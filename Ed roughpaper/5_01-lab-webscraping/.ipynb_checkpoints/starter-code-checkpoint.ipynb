# %%
# Import libaries
import pandas as pd
import requests
from bs4 import BeautifulSoup # Most common library for dealing with html

# %% [markdown]
# ### Step 1: Create a soup object from the home page

# %%
url = 'https://pages.git.generalassemb.ly/rldaggie/for-scraping/'
restaurants = requests.get(url)

# %%
restaurants.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(restaurants.content)

# %% [markdown]
# ### Step 2: Scrape the home page soup for every restaurant
#
# Note: Your best bet is to create a list of dictionaries, one for each restaurant. Each dictionary contains the restaurant's name and path from the `href`. The result of your scrape should look something like this:
#
# ```python
# restaurants = [
#     {'name': 'A&W Restaurants', 'href': 'restaurants/1.html'},
#     {'name': "Applebee's", 'href': 'restaurants/2.html'},
#     ...
# ]
# ```

# %%
# Find restaurant name
soup.find('table', {'id': 'restaurants'}).find('td').text.strip()
# Out:
# 'A&W Restaurants'

# %%
# Find restaurant href
soup.find('table', {'id': 'restaurants'}).find('td').find('a').attrs['href']
# Out:
# 'restaurants/1.html'

# %%
href_list = [element.find('a').attrs['href'] for element in soup.find_all('td')]
href_list[:2]
# Out:
# ['restaurants/1.html', 'restaurants/2.html']

# %%
# Scrape and create dataframe
rests = []
for element in soup.find('table', {'id': 'restaurants'}).find_all('td'):
    rest = {}
    rest['name'] = element.text.strip()
    rest['href'] = element.find('a').attrs['href']
    rests.append(rest)
    
rests[:2]
# Out:
# [{'name': 'A&W Restaurants', 'href': 'restaurants/1.html'},
#  {'name': "Applebee's", 'href': 'restaurants/2.html'}]

# %% [markdown]
# ### Step 3: Using the `href`, scrape each restaurant's page and create a single list of food dictionaries.
#
# Your list of foods should look something like this:
# ```python
# foods = [
#     {
#         'calories': '0',
#         'carbs': '0',
#         'category': 'Drinks',
#         'fat': '0',
#         'name': 'A&W® Diet Root Beer',
#         'restaurant': 'A&W Restaurants'
#     },
#     {
#         'calories': '0',
#         'carbs': '0',
#         'category': 'Drinks',
#         'fat': '0',
#         'name': 'A&W® Diet Root Beer',
#         'restaurant': 'A&W Restaurants'
#     },
#     ...
# ]
# ```
#
# **Note**: Remove extra white space from each category

# %%
url_rest = url + rests[0]['href']
each_rest = requests.get(url_rest)
each_rest_soup = BeautifulSoup(each_rest.content)

# %%
for rest_index, rest_dict in enumerate(rests):
    print(rest_index)
    print(rests[rest_index]['name'])
    print(rests[rest_index]['href'])
# Out:
# 0
# A&W Restaurants
# restaurants/1.html
# 1
# Applebee's
# restaurants/2.html
# 2
# Arby's
# restaurants/3.html
# 3
# Atlanta Bread Company
# restaurants/4.html
# 4
# Bojangle's Famous Chicken 'n Biscuits
# restaurants/5.html
# 5
# Buffalo Wild Wings
# restaurants/6.html
# 6
# Burger King
# restaurants/7.html
# 7
# Captain D's
# restaurants/8.html
# 8
# Carl's Jr.
# restaurants/9.html
# 9
# Charley's Grilled Subs
# restaurants/10.html
# 10
# Chick-fil-A
# restaurants/11.html
# 11
# Chili's
# restaurants/12.html
# 12
# Chipotle Mexican Grill
# restaurants/13.html
# 13
# Church's
# restaurants/14.html
# 14
# Corner Bakery Cafe
# restaurants/15.html
# 15
# Dairy Queen
# restaurants/16.html
# 16
# Denny's
# restaurants/17.html
# 17
# El Pollo Loco
# restaurants/18.html
# 18
# FATZ
# restaurants/19.html
# 19
# Fazoli's
# restaurants/20.html
# 20
# Five Guys Burgers and Fries
# restaurants/21.html
# 21
# Golden Chick
# restaurants/22.html
# 22
# Hardee's
# restaurants/23.html
# 23
# IHOP
# restaurants/24.html
# 24
# In-N-Out Burger
# restaurants/25.html
# 25
# Jack in the Box
# restaurants/26.html
# 26
# Jimmy Johns
# restaurants/27.html
# 27
# Joe's Crab Shack
# restaurants/28.html
# 28
# KFC
# restaurants/29.html
# 29
# McDonald's
# restaurants/30.html
# 30
# O'Charley's
# restaurants/31.html
# 31
# Olive Garden
# restaurants/32.html
# 32
# Outback Steakhouse
# restaurants/33.html
# 33
# Panda Express
# restaurants/34.html
# 34
# Panera Bread
# restaurants/35.html
# 35
# Popeye's
# restaurants/36.html
# 36
# Quiznos
# restaurants/37.html
# 37
# Red Robin Gourmet Burgers
# restaurants/38.html
# 38
# Romano's Macaroni Grill
# restaurants/39.html
# 39
# Ruby Tuesday
# restaurants/40.html
# 40
# Subway
# restaurants/41.html
# 41
# Taco Bell
# restaurants/42.html
# 42
# Taco Bueno
# restaurants/43.html
# 43
# Wendy's
# restaurants/44.html

# %%
foods = []
for rest_index, rest_dict in enumerate(rests):
    url_rest = url + rests[rest_index]['href']
    each_rest = requests.get(url_rest)
    each_rest_soup = BeautifulSoup(each_rest.content)
    for element in each_rest_soup.find_all('tr')[1:]:
        food_dict = {}
        food_dict['calories'] = element.find_all('td')[2].text
        food_dict['category'] = element.find_all('td')[1].text
        food_dict['fat'] = element.find_all('td')[3].text
        food_dict['carbs'] = element.find_all('td')[4].text
        food_dict['name'] = element.find_all('td')[0].text
        food_dict['restaurant'] = rests[rest_index]['name']
        foods.append(food_dict)
foods
# Out:
# [{'calories': '760',
#   'category': 'Burgers',
#   'fat': '45',
#   'carbs': '45',
#   'name': 'Original Bacon Double Cheeseburger',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '340',
#   'category': 'Entrees',
#   'fat': '20',
#   'carbs': '26',
#   'name': 'Coney (Chili) Dog',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '370',
#   'category': 'French Fries',
#   'fat': '15',
#   'carbs': '49',
#   'name': 'Chili Fries',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '670',
#   'category': 'Shakes',
#   'fat': '29',
#   'carbs': '90',
#   'name': 'Strawberry Milkshake (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '820',
#   'category': 'Shakes',
#   'fat': '18',
#   'carbs': '150',
#   'name': 'A&W® Root Beer Freeze (large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '340',
#   'category': 'Desserts',
#   'fat': '9',
#   'carbs': '57',
#   'name': 'Caramel Sundae',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '420',
#   'category': 'Shakes',
#   'fat': '6',
#   'carbs': '86',
#   'name': 'Strawberry Banana Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '1010',
#   'category': 'Desserts',
#   'fat': '59',
#   'carbs': '152',
#   'name': 'Chocolate Fudge Blendrrr',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '420',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '105',
#   'name': 'Strawberry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '270',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '73',
#   'name': 'Watermelon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '480',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '119',
#   'name': 'Lime Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '880',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '232',
#   'name': 'A&W® Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '420',
#   'category': 'Burgers',
#   'fat': '21',
#   'carbs': '37',
#   'name': 'Cheeseburger',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '310',
#   'category': 'French Fries',
#   'fat': '12',
#   'carbs': '45',
#   'name': 'French Fries (Regular)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '1140',
#   'category': 'Sides',
#   'fat': '80',
#   'carbs': '54',
#   'name': 'Cheese Curds (Large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '700',
#   'category': 'Shakes',
#   'fat': '29',
#   'carbs': '100',
#   'name': 'Chocolate Milkshake (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '450',
#   'category': 'Shakes',
#   'fat': '8',
#   'carbs': '108',
#   'name': 'Orange Freeze (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '170',
#   'category': 'Shakes',
#   'fat': '5',
#   'carbs': '30',
#   'name': 'A&W® Diet Root Beer Float (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '610',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '121',
#   'name': 'Strawberry Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '140',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '38',
#   'name': 'Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '340',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '90',
#   'name': 'Cherry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '330',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '82',
#   'name': 'Lemon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '570',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '142',
#   'name': 'Blue Raspberry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '0',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'A&W® Diet Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '400',
#   'category': 'Chicken',
#   'fat': '15',
#   'carbs': '31',
#   'name': 'Grilled Chicken Sandwich',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '430',
#   'category': 'French Fries',
#   'fat': '17',
#   'carbs': '61',
#   'name': 'French Fries (Large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '190',
#   'category': 'Sides',
#   'fat': '6',
#   'carbs': '22',
#   'name': 'Chili',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '880',
#   'category': 'Shakes',
#   'fat': '36',
#   'carbs': '125',
#   'name': 'Chocolate Milkshake (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '600',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '142',
#   'name': 'Orange Freeze (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '170',
#   'category': 'Shakes',
#   'fat': '5',
#   'carbs': '30',
#   'name': 'A&W® Diet Root Beer Float (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '610',
#   'category': 'Shakes',
#   'fat': '9',
#   'carbs': '137',
#   'name': 'Orange Float (large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '700',
#   'category': 'Desserts',
#   'fat': '41',
#   'carbs': '103',
#   'name': "Reese's® Peanut Butter Fudge Blendrrr",
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '210',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '55',
#   'name': 'Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '530',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '138',
#   'name': 'Cherry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '440',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '110',
#   'name': 'Lemon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '740',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '182',
#   'name': 'Blue Raspberry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '0',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'A&W® Diet Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '680',
#   'category': 'Burgers',
#   'fat': '38',
#   'carbs': '44',
#   'name': 'Original Double Cheeseburger',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '380',
#   'category': 'Entrees',
#   'fat': '23',
#   'carbs': '28',
#   'name': 'Coney (Chili) Cheese Dog',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '350',
#   'category': 'Sides',
#   'fat': '16',
#   'carbs': '45',
#   'name': 'Breaded Onion Rings (Regular)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '840',
#   'category': 'Shakes',
#   'fat': '36',
#   'carbs': '113',
#   'name': 'Strawberry Milkshake (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '260',
#   'category': 'Shakes',
#   'fat': '8',
#   'carbs': '39',
#   'name': 'A&W® Diet Root Beer Freeze (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '330',
#   'category': 'Shakes',
#   'fat': '5',
#   'carbs': '70',
#   'name': 'A&W® Root Beer Float (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '680',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '137',
#   'name': 'Strawberry Banana Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '340',
#   'category': 'Desserts',
#   'fat': '12',
#   'carbs': '56',
#   'name': 'Oreo® Cookies & Cream Blendrrr',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '560',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '143',
#   'name': 'Strawberry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '360',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '99',
#   'name': 'Watermelon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '770',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '188',
#   'name': 'Lime Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '1760',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '464',
#   'name': 'A&W® Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '470',
#   'category': 'Burgers',
#   'fat': '25',
#   'carbs': '38',
#   'name': 'Papa Single Burger',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '310',
#   'category': 'Entrees',
#   'fat': '19',
#   'carbs': '23',
#   'name': 'Hot Dog (plain)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '390',
#   'category': 'French Fries',
#   'fat': '18',
#   'carbs': '50',
#   'name': 'Cheese Fries',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '740',
#   'category': 'Desserts',
#   'fat': '31',
#   'carbs': '97',
#   'name': "Reese's® Polar Swirl®",
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '480',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '89',
#   'name': 'A&W® Root Beer Freeze (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '350',
#   'category': 'Desserts',
#   'fat': '11',
#   'carbs': '54',
#   'name': 'Hot Fudge Sundae',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '390',
#   'category': 'Shakes',
#   'fat': '6',
#   'carbs': '78',
#   'name': 'Strawberry Banana Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '560',
#   'category': 'Desserts',
#   'fat': '32',
#   'carbs': '92',
#   'name': 'Chocolate Fudge Blendrrr',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '290',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '75',
#   'name': 'Strawberry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '900',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '224',
#   'name': 'Cherry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '380',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '94',
#   'name': 'Lime Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '440',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '116',
#   'name': 'A&W® Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '530',
#   'category': 'Burgers',
#   'fat': '30',
#   'carbs': '39',
#   'name': 'Original Bacon Cheeseburger ',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '350',
#   'category': 'Entrees',
#   'fat': '22',
#   'carbs': '26',
#   'name': 'Cheese Dog',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '480',
#   'category': 'Sides',
#   'fat': '27',
#   'carbs': '62',
#   'name': 'Breaded Onion Rings (Large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '720',
#   'category': 'Shakes',
#   'fat': '31',
#   'carbs': '97',
#   'name': 'Vanilla Milkshake (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '340',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '53',
#   'name': 'A&W® Diet Root Beer Freeze (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '350',
#   'category': 'Shakes',
#   'fat': '5',
#   'carbs': '77',
#   'name': 'A&W® Root Beer Float (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '360',
#   'category': 'Shakes',
#   'fat': '6',
#   'carbs': '70',
#   'name': 'Strawberry Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '430',
#   'category': 'Desserts',
#   'fat': '15',
#   'carbs': '72',
#   'name': 'Oreo® Cookies & Cream Blendrrr',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '190',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '51',
#   'name': 'Cherry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '460',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '124',
#   'name': 'Watermelon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '270',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '67',
#   'name': 'Blue Raspberry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '0',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'A&W® Diet Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '380',
#   'category': 'Burgers',
#   'fat': '19',
#   'carbs': '33',
#   'name': 'Hamburger',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '200',
#   'category': 'French Fries',
#   'fat': '8',
#   'carbs': '28',
#   'name': 'French Fries (Small/ Kids)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '570',
#   'category': 'Sides',
#   'fat': '40',
#   'carbs': '27',
#   'name': 'Cheese Curds (Regular)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '900',
#   'category': 'Shakes',
#   'fat': '39',
#   'carbs': '121',
#   'name': 'Vanilla Milkshake (medium',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '600',
#   'category': 'Shakes',
#   'fat': '18',
#   'carbs': '92',
#   'name': 'A&W® Diet Root Beer Freeze (large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '640',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '136',
#   'name': 'A&W® Root Beer Float (large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '370',
#   'category': 'Shakes',
#   'fat': '6',
#   'carbs': '74',
#   'name': 'Strawberry Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '650',
#   'category': 'Desserts',
#   'fat': '21',
#   'carbs': '109',
#   'name': 'Oreo® Cookies & Cream Blendrrr',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '300',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '79',
#   'name': 'Cherry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '720',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '197',
#   'name': 'Watermelon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '370',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '91',
#   'name': 'Blue Raspberry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '0',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'A&W® Diet Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '500',
#   'category': 'Chicken',
#   'fat': '29',
#   'carbs': '32',
#   'name': 'Chicken Strips- 3 pieces',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '280',
#   'category': 'Sides',
#   'fat': '13',
#   'carbs': '32',
#   'name': 'Corn Dog Nuggets® (Regular)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '710',
#   'category': 'Desserts',
#   'fat': '25',
#   'carbs': '107',
#   'name': "M&M's® Polar Swirl®",
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '260',
#   'category': 'Desserts',
#   'fat': '7',
#   'carbs': '41',
#   'name': 'Vanilla Cone (large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '300',
#   'category': 'Desserts',
#   'fat': '8',
#   'carbs': '47',
#   'name': 'Strawberry Sundae',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '480',
#   'category': 'Shakes',
#   'fat': '6',
#   'carbs': '104',
#   'name': 'Pineapple Banana Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '1360',
#   'category': 'Desserts',
#   'fat': '79',
#   'carbs': '203',
#   'name': "Reese's® Peanut Butter Fudge Blendrrr",
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '390',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '103',
#   'name': 'Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '450',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '112',
#   'name': 'Cherry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '890',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '221',
#   'name': 'Lemon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '220',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '58',
#   'name': 'A&W® Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '0',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'A&W® Diet Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '550',
#   'category': 'Chicken',
#   'fat': '25',
#   'carbs': '52',
#   'name': 'Crispy Chicken Sandwich',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '180',
#   'category': 'Sides',
#   'fat': '8',
#   'carbs': '20',
#   'name': 'Corn Dog Nuggets® (Small/ Kids)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '170',
#   'category': 'Sides',
#   'fat': '12',
#   'carbs': '2',
#   'name': 'Extra Burger Patty',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '200',
#   'category': 'Desserts',
#   'fat': '5',
#   'carbs': '32',
#   'name': 'Vanilla Cone (regular)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '970',
#   'category': 'Shakes',
#   'fat': '18',
#   'carbs': '223',
#   'name': 'Orange Freeze (medium)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '350',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '60',
#   'name': 'A&W® Diet Root Beer Float (large)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '400',
#   'category': 'Shakes',
#   'fat': '6',
#   'carbs': '85',
#   'name': 'Pineapple Banana Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '710',
#   'category': 'Desserts',
#   'fat': '41',
#   'carbs': '108',
#   'name': "Reese's® Peanut Butter Fudge Blendrrr",
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '250',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '66',
#   'name': 'Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '330',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '83',
#   'name': 'Cherry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '560',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '139',
#   'name': 'Lemon Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '160',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '43',
#   'name': 'A&W® Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '0',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'A&W® Diet Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '690',
#   'category': 'Burgers',
#   'fat': '39',
#   'carbs': '44',
#   'name': 'Papa Burger®',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '340',
#   'category': 'Seafood',
#   'fat': '19',
#   'carbs': '34',
#   'name': 'Crunchy Shrimp',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '410',
#   'category': 'French Fries',
#   'fat': '17',
#   'carbs': '52',
#   'name': 'Chili Cheese Fries',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '690',
#   'category': 'Desserts',
#   'fat': '24',
#   'carbs': '107',
#   'name': 'Oreo® Polar Swirl®',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '370',
#   'category': 'Shakes',
#   'fat': '8',
#   'carbs': '68',
#   'name': 'A&W® Root Beer Freeze (small)',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '320',
#   'category': 'Desserts',
#   'fat': '8',
#   'carbs': '53',
#   'name': 'Chocolate Sundae',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '750',
#   'category': 'Shakes',
#   'fat': '10',
#   'carbs': '160',
#   'name': 'Pineapple Banana Smoothee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '490',
#   'category': 'Desserts',
#   'fat': '30',
#   'carbs': '68',
#   'name': 'Chocolate Fudge Blendrrr',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '230',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '58',
#   'name': 'Strawberry Limeade',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '570',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '141',
#   'name': 'Cherry Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '280',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '69',
#   'name': 'Lime Slushee',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '270',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '72',
#   'name': 'A&W® Root Beer',
#   'restaurant': 'A&W Restaurants'},
#  {'calories': '180',
#   'category': 'Salads',
#   'fat': '15',
#   'carbs': '12',
#   'name': 'Applebee’s House Salad (without dressing)',
#   'restaurant': "Applebee's"},
#  {'calories': '430',
#   'category': 'Sides',
#   'fat': '28',
#   'carbs': '42',
#   'name': 'Baked Potato',
#   'restaurant': "Applebee's"},
#  {'calories': '1110',
#   'category': 'Appetizers',
#   'fat': '55',
#   'carbs': '83',
#   'name': 'Boneless Wings, Southern BBQ',
#   'restaurant': "Applebee's"},
#  {'calories': '580',
#   'category': 'Salads',
#   'fat': '30',
#   'carbs': '40',
#   'name': 'Bruschetta Chicken Salad, Half w/o dressing ',
#   'restaurant': "Applebee's"},
#  {'calories': '1130',
#   'category': 'Appetizers',
#   'fat': '87',
#   'carbs': '85',
#   'name': 'Cheese Quesadilla Grande',
#   'restaurant': "Applebee's"},
#  {'calories': '1440',
#   'category': 'Entrees',
#   'fat': '82',
#   'carbs': '107',
#   'name': 'Chicken Fettuccine Carbonara ',
#   'restaurant': "Applebee's"},
#  {'calories': '140',
#   'category': 'Soups',
#   'fat': '7',
#   'carbs': '12',
#   'name': 'Chicken Tortilla Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '1150',
#   'category': 'Sandwiches',
#   'fat': '67',
#   'carbs': '77',
#   'name': 'Classic Club House Grill',
#   'restaurant': "Applebee's"},
#  {'calories': '530',
#   'category': 'Sides',
#   'fat': '28',
#   'carbs': '63',
#   'name': 'Crunchy Onion Rings, Side',
#   'restaurant': "Applebee's"},
#  {'calories': '260',
#   'category': 'Soups',
#   'fat': '14',
#   'carbs': '16',
#   'name': 'French Onion Soup ',
#   'restaurant': "Applebee's"},
#  {'calories': '255',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '64',
#   'name': 'Frozen Lemonades',
#   'restaurant': "Applebee's"},
#  {'calories': '260',
#   'category': 'Salads',
#   'fat': '15',
#   'carbs': '20',
#   'name': 'Grilled Shrimp ‘N Spinach Salad',
#   'restaurant': "Applebee's"},
#  {'calories': '230',
#   'category': 'Salads',
#   'fat': '10',
#   'carbs': '11',
#   'name': 'Grilled Steak Caesar, Half w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '250',
#   'category': 'Entrees',
#   'fat': '12',
#   'carbs': '0',
#   'name': 'House Sirloin',
#   'restaurant': "Applebee's"},
#  {'calories': '80',
#   'category': "Kid's Meals",
#   'fat': '0',
#   'carbs': '20',
#   'name': 'Kids Grape Juice (6.75 oz)',
#   'restaurant': "Applebee's"},
#  {'calories': '390',
#   'category': "Kid's Meals",
#   'fat': '27',
#   'carbs': '23',
#   'name': 'Kids Mini Hamburger – 1',
#   'restaurant': "Applebee's"},
#  {'calories': '330',
#   'category': "Kid's Meals",
#   'fat': '14',
#   'carbs': '49',
#   'name': 'Kids Vanilla Sundae with Hershey’s Syrup',
#   'restaurant': "Applebee's"},
#  {'calories': '420',
#   'category': 'Salads',
#   'fat': '29',
#   'carbs': '25',
#   'name': 'Oriental Chicken Salad',
#   'restaurant': "Applebee's"},
#  {'calories': '820',
#   'category': 'Salads',
#   'fat': '48',
#   'carbs': '72',
#   'name': 'Pecan-Crusted Chicken Salad, Half',
#   'restaurant': "Applebee's"},
#  {'calories': '1330',
#   'category': 'Appetizers',
#   'fat': '82',
#   'carbs': '114',
#   'name': 'Queso Blanco',
#   'restaurant': "Applebee's"},
#  {'calories': '870',
#   'category': 'Salads',
#   'fat': '56',
#   'carbs': '52',
#   'name': 'Santa Fe Chicken Salad, Regular w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '1430',
#   'category': 'Entrees',
#   'fat': '60',
#   'carbs': '150',
#   'name': 'Sizzling Skillet Fajitas - Combo',
#   'restaurant': "Applebee's"},
#  {'calories': '1525',
#   'category': 'Appetizers',
#   'fat': '102',
#   'carbs': '124',
#   'name': 'Spinach & Artichoke Dip',
#   'restaurant': "Applebee's"},
#  {'calories': '450',
#   'category': 'Entrees',
#   'fat': '8',
#   'carbs': '73',
#   'name': 'Teriyaki Chicken Pasta ',
#   'restaurant': "Applebee's"},
#  {'calories': '650',
#   'category': 'Appetizers',
#   'fat': '47',
#   'carbs': '44',
#   'name': 'Trios Chicken Quesadilla Grande',
#   'restaurant': "Applebee's"},
#  {'calories': '560',
#   'category': 'Appetizers',
#   'fat': '39',
#   'carbs': '41',
#   'name': 'Trios Spinach Artichoke Dip',
#   'restaurant': "Applebee's"},
#  {'calories': '310',
#   'category': 'Seafood',
#   'fat': '5',
#   'carbs': '48',
#   'name': 'Weight Watchers® Spicy Pineapple Glazed Shrimp & Spinach ',
#   'restaurant': "Applebee's"},
#  {'calories': '180',
#   'category': 'Salads',
#   'fat': '15',
#   'carbs': '12',
#   'name': 'Applebee’s House Salad',
#   'restaurant': "Applebee's"},
#  {'calories': '750',
#   'category': 'Sandwiches',
#   'fat': '33',
#   'carbs': '50',
#   'name': 'Bacon Cheese Chicken Grill',
#   'restaurant': "Applebee's"},
#  {'calories': '1170',
#   'category': 'Appetizers',
#   'fat': '69',
#   'carbs': '67',
#   'name': 'Boneless Wings, Hot Buffalo',
#   'restaurant': "Applebee's"},
#  {'calories': '740',
#   'category': 'Salads',
#   'fat': '44',
#   'carbs': '45',
#   'name': 'Bruschetta Chicken Salad, Half ',
#   'restaurant': "Applebee's"},
#  {'calories': '970',
#   'category': 'Sandwiches',
#   'fat': '55',
#   'carbs': '60',
#   'name': 'California Turkey Club',
#   'restaurant': "Applebee's"},
#  {'calories': '560',
#   'category': 'Sandwiches',
#   'fat': '41',
#   'carbs': '45',
#   'name': 'Chicken Fajita Rollup',
#   'restaurant': "Applebee's"},
#  {'calories': '180',
#   'category': 'Soups',
#   'fat': '8',
#   'carbs': '18',
#   'name': 'Chicken Tortilla Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '290',
#   'category': 'Soups',
#   'fat': '20',
#   'carbs': '16',
#   'name': 'Clam Chowder',
#   'restaurant': "Applebee's"},
#  {'calories': '1290',
#   'category': 'Appetizers',
#   'fat': '56',
#   'carbs': '181',
#   'name': 'Crunchy Onion Rings',
#   'restaurant': "Applebee's"},
#  {'calories': '590',
#   'category': 'Burgers',
#   'fat': '36',
#   'carbs': '50',
#   'name': 'French Dip Sliders',
#   'restaurant': "Applebee's"},
#  {'calories': '390',
#   'category': "Kid's Meals",
#   'fat': '18',
#   'carbs': '53',
#   'name': 'Fries, Side',
#   'restaurant': "Applebee's"},
#  {'calories': '470',
#   'category': 'Chicken',
#   'fat': '16',
#   'carbs': '30',
#   'name': 'Grilled Dijon Chicken & Portobellos ',
#   'restaurant': "Applebee's"},
#  {'calories': '460',
#   'category': 'Salads',
#   'fat': '34',
#   'carbs': '13',
#   'name': 'Grilled Steak Caesar, Half',
#   'restaurant': "Applebee's"},
#  {'calories': '310',
#   'category': 'Entrees',
#   'fat': '13',
#   'carbs': '0',
#   'name': 'House Sirloin',
#   'restaurant': "Applebee's"},
#  {'calories': '230',
#   'category': "Kid's Meals",
#   'fat': '14',
#   'carbs': '16',
#   'name': 'Kids Fried Shrimp',
#   'restaurant': "Applebee's"},
#  {'calories': '740',
#   'category': "Kid's Meals",
#   'fat': '46',
#   'carbs': '47',
#   'name': 'Kids Mini Cheeseburgers – 2',
#   'restaurant': "Applebee's"},
#  {'calories': '230',
#   'category': "Kid's Meals",
#   'fat': '14',
#   'carbs': '24',
#   'name': 'Kids Vanilla Sundae',
#   'restaurant': "Applebee's"},
#  {'calories': '1160',
#   'category': 'Sandwiches',
#   'fat': '60',
#   'carbs': '121',
#   'name': 'Oriental Chicken Rollup',
#   'restaurant': "Applebee's"},
#  {'calories': '590',
#   'category': 'Salads',
#   'fat': '19',
#   'carbs': '58',
#   'name': 'Oriental Grilled Chicken Salad, Regular w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '1240',
#   'category': 'Burgers',
#   'fat': '103',
#   'carbs': '44',
#   'name': 'Quesadilla Burger',
#   'restaurant': "Applebee's"},
#  {'calories': '1240',
#   'category': 'Salads',
#   'fat': '93',
#   'carbs': '58',
#   'name': 'Santa Fe Chicken Salad, Regular',
#   'restaurant': "Applebee's"},
#  {'calories': '1370',
#   'category': 'Entrees',
#   'fat': '52',
#   'carbs': '149',
#   'name': 'Sizzling Skillet Fajitas - Chicken',
#   'restaurant': "Applebee's"},
#  {'calories': '1610',
#   'category': 'Appetizers',
#   'fat': '103',
#   'carbs': '125',
#   'name': 'Spicy Chili Cheese Nachos',
#   'restaurant': "Applebee's"},
#  {'calories': '1090',
#   'category': 'Sandwiches',
#   'fat': '58',
#   'carbs': '90',
#   'name': 'Stuffed Meatball Sandwich',
#   'restaurant': "Applebee's"},
#  {'calories': '880',
#   'category': 'Appetizers',
#   'fat': '59',
#   'carbs': '55',
#   'name': 'Trios Cheeseburger Sliders',
#   'restaurant': "Applebee's"},
#  {'calories': '520',
#   'category': 'Appetizers',
#   'fat': '33',
#   'carbs': '40',
#   'name': 'Trios Spicy Queso Blanco',
#   'restaurant': "Applebee's"},
#  {'calories': '340',
#   'category': 'Salads',
#   'fat': '4',
#   'carbs': '6',
#   'name': 'Weight Watchers® Paradise Chicken Salad ',
#   'restaurant': "Applebee's"},
#  {'calories': '2375',
#   'category': 'Appetizers',
#   'fat': '162',
#   'carbs': '169',
#   'name': 'Appetizer Sampler',
#   'restaurant': "Applebee's"},
#  {'calories': '1115',
#   'category': 'Ribs',
#   'fat': '55',
#   'carbs': '92',
#   'name': 'Applebee’s Riblets Basket  ',
#   'restaurant': "Applebee's"},
#  {'calories': '190',
#   'category': 'Soups',
#   'fat': '9',
#   'carbs': '21',
#   'name': 'Black Bean Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '290',
#   'category': 'Sides',
#   'fat': '19',
#   'carbs': '22',
#   'name': 'Breadstick',
#   'restaurant': "Applebee's"},
#  {'calories': '1170',
#   'category': 'Entrees',
#   'fat': '69',
#   'carbs': '95',
#   'name': 'Cajun Shrimp Pasta ',
#   'restaurant': "Applebee's"},
#  {'calories': '1330',
#   'category': 'Burgers',
#   'fat': '87',
#   'carbs': '83',
#   'name': 'Cheeseburger Sliders with Applewood Smoked Bacon',
#   'restaurant': "Applebee's"},
#  {'calories': '110',
#   'category': 'Soups',
#   'fat': '3',
#   'carbs': '11',
#   'name': 'Chicken Noodle Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '1680',
#   'category': 'Appetizers',
#   'fat': '107',
#   'carbs': '134',
#   'name': 'Chili Cheese Nachos',
#   'restaurant': "Applebee's"},
#  {'calories': '660',
#   'category': 'Appetizers',
#   'fat': '35',
#   'carbs': '25',
#   'name': 'Classic Wings, Southern BBQ',
#   'restaurant': "Applebee's"},
#  {'calories': '935',
#   'category': 'Ribs',
#   'fat': '49',
#   'carbs': '88',
#   'name': 'Double-Glazed Baby Back Ribs - Half Rack  ',
#   'restaurant': "Applebee's"},
#  {'calories': '310',
#   'category': 'Salads',
#   'fat': '23',
#   'carbs': '12',
#   'name': 'Fried Chicken Salad, Half w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '180',
#   'category': 'Salads',
#   'fat': '5',
#   'carbs': '10',
#   'name': 'Grilled Chicken Caesar, Half w/o dressing ',
#   'restaurant': "Applebee's"},
#  {'calories': '680',
#   'category': 'Salads',
#   'fat': '51',
#   'carbs': '20',
#   'name': 'Grilled Shrimp ‘N Spinach Salad, Regular w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '1570',
#   'category': 'Seafood',
#   'fat': '106',
#   'carbs': '108',
#   'name': 'Hand-Battered Fish & Chips ',
#   'restaurant': "Applebee's"},
#  {'calories': '220',
#   'category': "Kid's Meals",
#   'fat': '22',
#   'carbs': '5',
#   'name': 'Kids Celery side with Dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '330',
#   'category': "Kid's Meals",
#   'fat': '18',
#   'carbs': '31',
#   'name': 'Kids Hot Dog',
#   'restaurant': "Applebee's"},
#  {'calories': '360',
#   'category': "Kid's Meals",
#   'fat': '19',
#   'carbs': '43',
#   'name': 'Kids OREO® Cookie Sundae',
#   'restaurant': "Applebee's"},
#  {'calories': '800',
#   'category': 'Chicken',
#   'fat': '30',
#   'carbs': '67',
#   'name': 'Margherita Chicken ',
#   'restaurant': "Applebee's"},
#  {'calories': '680',
#   'category': 'Salads',
#   'fat': '41',
#   'carbs': '50',
#   'name': 'Oriental Chicken Salad, Regular w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '1130',
#   'category': 'Burgers',
#   'fat': '67',
#   'carbs': '70',
#   'name': 'Philly Burger',
#   'restaurant': "Applebee's"},
#  {'calories': '1295',
#   'category': 'Chicken',
#   'fat': '73',
#   'carbs': '103',
#   'name': 'Riblet and Chicken Tenders Basket ',
#   'restaurant': "Applebee's"},
#  {'calories': '500',
#   'category': 'Entrees',
#   'fat': '21',
#   'carbs': '31',
#   'name': 'Signature Sirloin with Garlic Herb Shrimp',
#   'restaurant': "Applebee's"},
#  {'calories': '1050',
#   'category': 'Entrees',
#   'fat': '65',
#   'carbs': '49',
#   'name': 'Sizzling Steak & Cheese',
#   'restaurant': "Applebee's"},
#  {'calories': '600',
#   'category': 'Entrees',
#   'fat': '15',
#   'carbs': '37',
#   'name': 'Steak & Honey BBQ Chicken Combo',
#   'restaurant': "Applebee's"},
#  {'calories': '1120',
#   'category': 'Sides',
#   'fat': '78',
#   'carbs': '89',
#   'name': 'Toasted Garlic Bread Basket ',
#   'restaurant': "Applebee's"},
#  {'calories': '620',
#   'category': 'Appetizers',
#   'fat': '28',
#   'carbs': '58',
#   'name': 'Trios Boneless Wings, Honey BBQ',
#   'restaurant': "Applebee's"},
#  {'calories': '330',
#   'category': 'Appetizers',
#   'fat': '17',
#   'carbs': '13',
#   'name': 'Trios Classic Wings, Southern BBQ',
#   'restaurant': "Applebee's"},
#  {'calories': '820',
#   'category': 'Desserts',
#   'fat': '48',
#   'carbs': '97',
#   'name': 'Triple Chocolate Meltdown® ',
#   'restaurant': "Applebee's"},
#  {'calories': '495',
#   'category': 'Appetizers',
#   'fat': '23',
#   'carbs': '45',
#   'name': 'Wonton Tacos',
#   'restaurant': "Applebee's"},
#  {'calories': '630',
#   'category': 'Salads',
#   'fat': '43',
#   'carbs': '33',
#   'name': 'Apple Walnut Chicken Salad, Half',
#   'restaurant': "Applebee's"},
#  {'calories': '1705',
#   'category': 'Ribs',
#   'fat': '86',
#   'carbs': '134',
#   'name': 'Applebee’s Riblets Platter  ',
#   'restaurant': "Applebee's"},
#  {'calories': '740',
#   'category': 'Sandwiches',
#   'fat': '42',
#   'carbs': '54',
#   'name': 'Blackened Tilapia Sandwich',
#   'restaurant': "Applebee's"},
#  {'calories': '340',
#   'category': 'Soups',
#   'fat': '26',
#   'carbs': '19',
#   'name': 'Broccoli Cheddar Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '500',
#   'category': 'Salads',
#   'fat': '42',
#   'carbs': '16',
#   'name': 'California Shrimp Salad, Half ',
#   'restaurant': "Applebee's"},
#  {'calories': '350',
#   'category': 'Sides',
#   'fat': '20',
#   'carbs': '28',
#   'name': 'Cheesy Corn ',
#   'restaurant': "Applebee's"},
#  {'calories': '1690',
#   'category': 'Chicken',
#   'fat': '95',
#   'carbs': '130',
#   'name': 'Chicken Parmesan Stack ',
#   'restaurant': "Applebee's"},
#  {'calories': '960',
#   'category': 'Appetizers',
#   'fat': '53',
#   'carbs': '106',
#   'name': 'Chips and Spicy Chipotle Lime Salsa',
#   'restaurant': "Applebee's"},
#  {'calories': '690',
#   'category': 'Appetizers',
#   'fat': '35',
#   'carbs': '32',
#   'name': 'Classic Wings, Sweet & spicy sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '1160',
#   'category': 'Chicken',
#   'fat': '67',
#   'carbs': '94',
#   'name': 'Fiesta Lime Chicken® ',
#   'restaurant': "Applebee's"},
#  {'calories': '980',
#   'category': 'Salads',
#   'fat': '79',
#   'carbs': '50',
#   'name': 'Fried Chicken Salad, Regular',
#   'restaurant': "Applebee's"},
#  {'calories': '820',
#   'category': 'Salads',
#   'fat': '57',
#   'carbs': '25',
#   'name': 'Grilled Chicken Caesar, Regular ',
#   'restaurant': "Applebee's"},
#  {'calories': '860',
#   'category': 'Sandwiches',
#   'fat': '58',
#   'carbs': '63',
#   'name': 'Hand-Battered Fish Sandwich',
#   'restaurant': "Applebee's"},
#  {'calories': '550',
#   'category': "Kid's Meals",
#   'fat': '31',
#   'carbs': '44',
#   'name': 'Kids Cheese Pizza',
#   'restaurant': "Applebee's"},
#  {'calories': '350',
#   'category': "Kid's Meals",
#   'fat': '18',
#   'carbs': '45',
#   'name': 'Kids Hot Fudge Sundae',
#   'restaurant': "Applebee's"},
#  {'calories': '360',
#   'category': "Kid's Meals",
#   'fat': '7',
#   'carbs': '60',
#   'name': 'Kids Pasta with Marinara Sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '940',
#   'category': 'Appetizers',
#   'fat': '48',
#   'carbs': '84',
#   'name': 'Mozzarella Sticks',
#   'restaurant': "Applebee's"},
#  {'calories': '430',
#   'category': 'Salads',
#   'fat': '21',
#   'carbs': '36',
#   'name': 'Oriental Grilled Chicken Salad',
#   'restaurant': "Applebee's"},
#  {'calories': '820',
#   'category': 'Appetizers',
#   'fat': '41',
#   'carbs': '68',
#   'name': 'Pork Wonton Tacos',
#   'restaurant': "Applebee's"},
#  {'calories': '1800',
#   'category': 'Chicken',
#   'fat': '101',
#   'carbs': '136',
#   'name': 'Riblet and Chicken Tenders Platter ',
#   'restaurant': "Applebee's"},
#  {'calories': '900',
#   'category': 'Desserts',
#   'fat': '33',
#   'carbs': '145',
#   'name': 'Sizzling Apple Pie ',
#   'restaurant': "Applebee's"},
#  {'calories': '980',
#   'category': 'Sandwiches',
#   'fat': '50',
#   'carbs': '101',
#   'name': 'Slow Simmered Tender Beef Sandwich',
#   'restaurant': "Applebee's"},
#  {'calories': '985',
#   'category': 'Entrees',
#   'fat': '49',
#   'carbs': '39',
#   'name': 'Steak & Riblets Combo',
#   'restaurant': "Applebee's"},
#  {'calories': '220',
#   'category': 'Soups',
#   'fat': '13',
#   'carbs': '22',
#   'name': 'Tomato Basil Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '590',
#   'category': 'Appetizers',
#   'fat': '35',
#   'carbs': '33',
#   'name': 'Trios Boneless Wings, Hot Buffalo',
#   'restaurant': "Applebee's"},
#  {'calories': '350',
#   'category': 'Appetizers',
#   'fat': '18',
#   'carbs': '16',
#   'name': 'Trios Classic Wings, Sweet & spicy sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '550',
#   'category': 'Burgers',
#   'fat': '22',
#   'carbs': '60',
#   'name': 'Veggie Burger',
#   'restaurant': "Applebee's"},
#  {'calories': '1150',
#   'category': 'Sandwiches',
#   'fat': '73',
#   'carbs': '76',
#   'name': 'Zesty Ranch Chicken Sandwich',
#   'restaurant': "Applebee's"},
#  {'calories': '130',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '59',
#   'name': 'Applebee’s Limeades',
#   'restaurant': "Applebee's"},
#  {'calories': '420',
#   'category': 'Soups',
#   'fat': '32',
#   'carbs': '27',
#   'name': 'Baked Potato Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '1150',
#   'category': 'Appetizers',
#   'fat': '55',
#   'carbs': '90',
#   'name': 'Boneless Wings, Sweet & spicy sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '1110',
#   'category': 'Salads',
#   'fat': '66',
#   'carbs': '67',
#   'name': 'Bruschetta Chicken Salad, Regular ',
#   'restaurant': "Applebee's"},
#  {'calories': '940',
#   'category': 'Burgers',
#   'fat': '58',
#   'carbs': '52',
#   'name': 'Cheeseburger',
#   'restaurant': "Applebee's"},
#  {'calories': '1230',
#   'category': 'Chicken',
#   'fat': '59',
#   'carbs': '112',
#   'name': 'Chicken Fried Chicken ',
#   'restaurant': "Applebee's"},
#  {'calories': '310',
#   'category': 'Soups',
#   'fat': '26',
#   'carbs': '10',
#   'name': 'Chili',
#   'restaurant': "Applebee's"},
#  {'calories': '710',
#   'category': 'Appetizers',
#   'fat': '49',
#   'carbs': '8',
#   'name': 'Classic Wings, Classic Buffalo',
#   'restaurant': "Applebee's"},
#  {'calories': '915',
#   'category': 'Shakes',
#   'fat': '46',
#   'carbs': '109',
#   'name': 'Decadent Shakes',
#   'restaurant': "Applebee's"},
#  {'calories': '90',
#   'category': 'Sides',
#   'fat': '0',
#   'carbs': '24',
#   'name': 'Fresh Fruit, Side',
#   'restaurant': "Applebee's"},
#  {'calories': '690',
#   'category': 'Seafood',
#   'fat': '29',
#   'carbs': '61',
#   'name': 'Garlic Herb Salmon ',
#   'restaurant': "Applebee's"},
#  {'calories': '620',
#   'category': 'Salads',
#   'fat': '44',
#   'carbs': '33',
#   'name': 'Grilled Shrimp ‘N Spinach Salad, Half',
#   'restaurant': "Applebee's"},
#  {'calories': '910',
#   'category': 'Salads',
#   'fat': '68',
#   'carbs': '25',
#   'name': 'Grilled Steak Caesar, Regular',
#   'restaurant': "Applebee's"},
#  {'calories': '140',
#   'category': "Kid's Meals",
#   'fat': '7',
#   'carbs': '0',
#   'name': 'Kids 4oz Sirloin Steak',
#   'restaurant': "Applebee's"},
#  {'calories': '610',
#   'category': "Kid's Meals",
#   'fat': '36',
#   'carbs': '51',
#   'name': 'Kids Grilled Cheese (Hawaiian bread)',
#   'restaurant': "Applebee's"},
#  {'calories': '660',
#   'category': "Kid's Meals",
#   'fat': '40',
#   'carbs': '46',
#   'name': 'Kids Mini Hamburger – 2',
#   'restaurant': "Applebee's"},
#  {'calories': '500',
#   'category': 'Sides',
#   'fat': '35',
#   'carbs': '42',
#   'name': 'Loaded Baked Potato  ',
#   'restaurant': "Applebee's"},
#  {'calories': '670',
#   'category': 'Salads',
#   'fat': '49',
#   'carbs': '42',
#   'name': 'Oriental Chicken Salad, Half',
#   'restaurant': "Applebee's"},
#  {'calories': '580',
#   'category': 'Salads',
#   'fat': '31',
#   'carbs': '53',
#   'name': 'Pecan-Crusted Chicken Salad, Half w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '1440',
#   'category': 'Appetizers',
#   'fat': '89',
#   'carbs': '118',
#   'name': 'Queso Blanco with chili',
#   'restaurant': "Applebee's"},
#  {'calories': '42',
#   'category': 'Sides',
#   'fat': '0',
#   'carbs': '8',
#   'name': 'Seasonal Vegetables, Side',
#   'restaurant': "Applebee's"},
#  {'calories': '1400',
#   'category': 'Entrees',
#   'fat': '65',
#   'carbs': '151',
#   'name': 'Sizzling Skillet Fajitas - Shrimp',
#   'restaurant': "Applebee's"},
#  {'calories': '230',
#   'category': 'Salads',
#   'fat': '15',
#   'carbs': '19',
#   'name': 'Spinach Salad',
#   'restaurant': "Applebee's"},
#  {'calories': '440',
#   'category': 'Entrees',
#   'fat': '8',
#   'carbs': '74',
#   'name': 'Teriyaki Shrimp Pasta ',
#   'restaurant': "Applebee's"},
#  {'calories': '130',
#   'category': 'Sides',
#   'fat': '12',
#   'carbs': '4',
#   'name': 'Topper - Sautéed Garlic Mushrooms',
#   'restaurant': "Applebee's"},
#  {'calories': '360',
#   'category': 'Appetizers',
#   'fat': '24',
#   'carbs': '4',
#   'name': 'Trios Classic Wings, Classic Buffalo',
#   'restaurant': "Applebee's"},
#  {'calories': '560',
#   'category': 'Appetizers',
#   'fat': '38',
#   'carbs': '37',
#   'name': 'Trios Steak Quesadilla Towers',
#   'restaurant': "Applebee's"},
#  {'calories': '380',
#   'category': 'Salads',
#   'fat': '12',
#   'carbs': '32',
#   'name': 'Weight Watchers® Steak & Potato Salad ',
#   'restaurant': "Applebee's"},
#  {'calories': '230',
#   'category': 'Sides',
#   'fat': '17',
#   'carbs': '2',
#   'name': 'Add Grilled Shrimp ',
#   'restaurant': "Applebee's"},
#  {'calories': '630',
#   'category': 'Sandwiches',
#   'fat': '47',
#   'carbs': '25',
#   'name': 'Applebee’s Reuben',
#   'restaurant': "Applebee's"},
#  {'calories': '1030',
#   'category': 'Burgers',
#   'fat': '48',
#   'carbs': '90',
#   'name': 'BBQ Pulled Pork Sliders',
#   'restaurant': "Applebee's"},
#  {'calories': '760',
#   'category': 'Entrees',
#   'fat': '44',
#   'carbs': '35',
#   'name': 'Bourbon Street Steak',
#   'restaurant': "Applebee's"},
#  {'calories': '220',
#   'category': 'Salads',
#   'fat': '19',
#   'carbs': '8',
#   'name': 'Caesar Salad',
#   'restaurant': "Applebee's"},
#  {'calories': '1330',
#   'category': 'Burgers',
#   'fat': '87',
#   'carbs': '83',
#   'name': 'Cheeseburger Sliders add bacon',
#   'restaurant': "Applebee's"},
#  {'calories': '160',
#   'category': 'Soups',
#   'fat': '4',
#   'carbs': '17',
#   'name': 'Chicken Noodle Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '550',
#   'category': 'French Fries',
#   'fat': '33',
#   'carbs': '59',
#   'name': 'Chili Cheese Fries, Side',
#   'restaurant': "Applebee's"},
#  {'calories': '720',
#   'category': 'Appetizers',
#   'fat': '49',
#   'carbs': '9',
#   'name': 'Classic Wings, Hot Buffalo',
#   'restaurant': "Applebee's"},
#  {'calories': '1345',
#   'category': 'Ribs',
#   'fat': '72',
#   'carbs': '95',
#   'name': 'Double-Glazed Baby Back Ribs  ',
#   'restaurant': "Applebee's"},
#  {'calories': '530',
#   'category': 'Salads',
#   'fat': '42',
#   'carbs': '26',
#   'name': 'Fried Chicken Salad, Half',
#   'restaurant': "Applebee's"},
#  {'calories': '410',
#   'category': 'Salads',
#   'fat': '29',
#   'carbs': '12',
#   'name': 'Grilled Chicken Caesar, Half',
#   'restaurant': "Applebee's"},
#  {'calories': '1010',
#   'category': 'Salads',
#   'fat': '69',
#   'carbs': '63',
#   'name': 'Grilled Shrimp ‘N Spinach Salad, Regular',
#   'restaurant': "Applebee's"},
#  {'calories': '790',
#   'category': 'Burgers',
#   'fat': '46',
#   'carbs': '50',
#   'name': 'Hamburger',
#   'restaurant': "Applebee's"},
#  {'calories': '50',
#   'category': "Kid's Meals",
#   'fat': '0',
#   'carbs': '27',
#   'name': 'Kids Applesauce side',
#   'restaurant': "Applebee's"},
#  {'calories': '230',
#   'category': "Kid's Meals",
#   'fat': '5',
#   'carbs': '23',
#   'name': 'Kids Grilled Chicken Sandwich',
#   'restaurant': "Applebee's"},
#  {'calories': '780',
#   'category': "Kid's Meals",
#   'fat': '41',
#   'carbs': '97',
#   'name': 'Kids OREO® Cookie Milkshake',
#   'restaurant': "Applebee's"},
#  {'calories': '1100',
#   'category': 'Desserts',
#   'fat': '63',
#   'carbs': '115',
#   'name': 'Maple Butter Blondie ',
#   'restaurant': "Applebee's"},
#  {'calories': '1340',
#   'category': 'Salads',
#   'fat': '98',
#   'carbs': '85',
#   'name': 'Oriental Chicken Salad, Regular',
#   'restaurant': "Applebee's"},
#  {'calories': '880',
#   'category': 'Salads',
#   'fat': '46',
#   'carbs': '76',
#   'name': 'Pecan-Crusted Chicken Salad, Regular w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '670',
#   'category': 'Entrees',
#   'fat': '47',
#   'carbs': '3',
#   'name': 'Ribeye',
#   'restaurant': "Applebee's"},
#  {'calories': '143',
#   'category': 'Entrees',
#   'fat': '81',
#   'carbs': '113',
#   'name': 'Shrimp Fettuccine Alfredo ',
#   'restaurant': "Applebee's"},
#  {'calories': '1170',
#   'category': 'Entrees',
#   'fat': '59',
#   'carbs': '78',
#   'name': 'Sizzling Smokehouse Chicken Stack ',
#   'restaurant': "Applebee's"},
#  {'calories': '540',
#   'category': 'Entrees',
#   'fat': '36',
#   'carbs': '2',
#   'name': 'Steak & Grilled Shrimp Combo',
#   'restaurant': "Applebee's"},
#  {'calories': '1460',
#   'category': 'Entrees',
#   'fat': '75',
#   'carbs': '127',
#   'name': 'Three-Cheese Chicken Penne ',
#   'restaurant': "Applebee's"},
#  {'calories': '580',
#   'category': 'Appetizers',
#   'fat': '35',
#   'carbs': '33',
#   'name': 'Trios Boneless Wings, Classic Buffalo',
#   'restaurant': "Applebee's"},
#  {'calories': '360',
#   'category': 'Appetizers',
#   'fat': '25',
#   'carbs': '4',
#   'name': 'Trios Classic Wings, Hot Buffalo',
#   'restaurant': "Applebee's"},
#  {'calories': '200',
#   'category': 'Appetizers',
#   'fat': '21',
#   'carbs': '1',
#   'name': 'Trios Wings Ranch Dipping Sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '200',
#   'category': 'Appetizers',
#   'fat': '21',
#   'carbs': '1',
#   'name': 'Wings Ranch Dipping Sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '390',
#   'category': 'Sides',
#   'fat': '21',
#   'carbs': '35',
#   'name': 'Add Fried Shrimp  ',
#   'restaurant': "Applebee's"},
#  {'calories': '1140',
#   'category': 'Sandwiches',
#   'fat': '81',
#   'carbs': '49',
#   'name': 'Applebee’s Reuben',
#   'restaurant': "Applebee's"},
#  {'calories': '360',
#   'category': 'Soups',
#   'fat': '28',
#   'carbs': '20',
#   'name': 'Baked Potato Soup',
#   'restaurant': "Applebee's"},
#  {'calories': '750',
#   'category': 'Entrees',
#   'fat': '45',
#   'carbs': '31',
#   'name': 'Bourbon Street Chicken & Shrimp',
#   'restaurant': "Applebee's"},
#  {'calories': '790',
#   'category': 'Salads',
#   'fat': '36',
#   'carbs': '56',
#   'name': 'Bruschetta Chicken Salad, Regular w/o dressing ',
#   'restaurant': "Applebee's"},
#  {'calories': '1270',
#   'category': 'Burgers',
#   'fat': '82',
#   'carbs': '82',
#   'name': 'Cheeseburger Sliders',
#   'restaurant': "Applebee's"},
#  {'calories': '1260',
#   'category': 'Entrees',
#   'fat': '61',
#   'carbs': '118',
#   'name': 'Chicken Fried Steak (includes mashed potato, gravy & vegetable)',
#   'restaurant': "Applebee's"},
#  {'calories': '370',
#   'category': 'Soups',
#   'fat': '28',
#   'carbs': '16',
#   'name': 'Chili ',
#   'restaurant': "Applebee's"},
#  {'calories': '790',
#   'category': 'Appetizers',
#   'fat': '35',
#   'carbs': '59',
#   'name': 'Classic Wings, Honey BBQ',
#   'restaurant': "Applebee's"},
#  {'calories': '1280',
#   'category': 'Seafood',
#   'fat': '69',
#   'carbs': '133',
#   'name': 'Double Crunch Shrimp ',
#   'restaurant': "Applebee's"},
#  {'calories': '380',
#   'category': 'Salads',
#   'fat': '27',
#   'carbs': '20',
#   'name': 'Fried Chicken Salad',
#   'restaurant': "Applebee's"},
#  {'calories': '330',
#   'category': 'Sides',
#   'fat': '18',
#   'carbs': '38',
#   'name': 'Garlic Mashed Potatoes  ',
#   'restaurant': "Applebee's"},
#  {'calories': '460',
#   'category': 'Salads',
#   'fat': '35',
#   'carbs': '12',
#   'name': 'Grilled Shrimp ‘N Spinach Salad, Half w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '460',
#   'category': 'Salads',
#   'fat': '21',
#   'carbs': '21',
#   'name': 'Grilled Steak Caesar, Regular w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '70',
#   'category': "Kid's Meals",
#   'fat': '0',
#   'carbs': '17',
#   'name': 'Kids Apple Juice (6.75 oz)',
#   'restaurant': "Applebee's"},
#  {'calories': '630',
#   'category': "Kid's Meals",
#   'fat': '36',
#   'carbs': '54',
#   'name': 'Kids Grilled Cheese (sourdough bread)',
#   'restaurant': "Applebee's"},
#  {'calories': '70',
#   'category': "Kid's Meals",
#   'fat': '0',
#   'carbs': '17',
#   'name': 'Kids Orange-Tangerine Juice (6.75 oz)',
#   'restaurant': "Applebee's"},
#  {'calories': '550',
#   'category': 'Sides',
#   'fat': '42',
#   'carbs': '41',
#   'name': 'Loaded Mashed Potatoes ',
#   'restaurant': "Applebee's"},
#  {'calories': '340',
#   'category': 'Salads',
#   'fat': '20',
#   'carbs': '25',
#   'name': 'Oriental Chicken Salad, Half w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '1350',
#   'category': 'Salads',
#   'fat': '80',
#   'carbs': '114',
#   'name': 'Pecan-Crusted Chicken Salad, Regular',
#   'restaurant': "Applebee's"},
#  {'calories': '290',
#   'category': 'Sides',
#   'fat': '6',
#   'carbs': '48',
#   'name': 'Red Beans & Rice  ',
#   'restaurant': "Applebee's"},
#  {'calories': '660',
#   'category': 'Entrees',
#   'fat': '42',
#   'carbs': '4',
#   'name': 'Shrimp ‘N Parmesan Sirloin',
#   'restaurant': "Applebee's"},
#  {'calories': '1410',
#   'category': 'Entrees',
#   'fat': '55',
#   'carbs': '152',
#   'name': 'Sizzling Skillet Fajitas - Steak',
#   'restaurant': "Applebee's"},
#  {'calories': '650',
#   'category': 'Entrees',
#   'fat': '34',
#   'carbs': '37',
#   'name': 'Steak & Fried Shrimp Combo',
#   'restaurant': "Applebee's"},
#  {'calories': '940',
#   'category': 'Entrees',
#   'fat': '49',
#   'carbs': '77',
#   'name': 'Three-Cheese Chicken Penne',
#   'restaurant': "Applebee's"},
#  {'calories': '230',
#   'category': 'Sides',
#   'fat': '15',
#   'carbs': '4',
#   'name': 'Topper - Shrimp ‘N Parmesan',
#   'restaurant': "Applebee's"},
#  {'calories': '400',
#   'category': 'Appetizers',
#   'fat': '17',
#   'carbs': '29',
#   'name': 'Trios Classic Wings, Honey BBQ',
#   'restaurant': "Applebee's"},
#  {'calories': '240',
#   'category': 'Appetizers',
#   'fat': '26',
#   'carbs': '1',
#   'name': 'Trios Wings Bleu Cheese Dipping Sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '240',
#   'category': 'Appetizers',
#   'fat': '26',
#   'carbs': '1',
#   'name': 'Wings Bleu Cheese Dipping Sauce',
#   'restaurant': "Applebee's"},
#  {'calories': '350',
#   'category': 'Salads',
#   'fat': '20',
#   'carbs': '15',
#   'name': 'Apple Walnut Chicken Salad, Half w/o dressing',
#   'restaurant': "Applebee's"},
#  {'calories': '380',
#   'category': 'Entrees',
#   'fat': '14',
#   'carbs': '25',
#   'name': 'Asiago Peppercorn Steak',
# ...
#   'name': 'Vanilla Milk Shake',
#   'restaurant': 'Burger King'},
#  {'calories': '420',
#   'category': 'Burgers',
#   'fat': '26',
#   'carbs': '30',
#   'name': 'BK Toppers™ Deluxe Cheeseburger',
#   'restaurant': 'Burger King'},
#  {'calories': '510',
#   'category': 'Sandwiches',
#   'fat': '23',
#   'carbs': '51',
#   'name': 'Whopper® Sandwich w/o Mayo',
#   'restaurant': 'Burger King'},
#  {'calories': '1070',
#   'category': 'Sandwiches',
#   'fat': '64',
#   'carbs': '53',
#   'name': 'Triple Whopper® Sandwich With Cheese w/o Mayo',
#   'restaurant': 'Burger King'},
#  {'calories': '300',
#   'category': 'Burgers',
#   'fat': '14',
#   'carbs': '28',
#   'name': 'Cheeseburger',
#   'restaurant': 'Burger King'},
#  {'calories': '470',
#   'category': 'Sandwiches',
#   'fat': '18',
#   'carbs': '40',
#   'name': 'Tendergrill® Chicken Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '300',
#   'category': 'Sandwiches',
#   'fat': '12',
#   'carbs': '35',
#   'name': "Spicy Chick'n Crisp® Sandwich w/o Mayo",
#   'restaurant': 'Burger King'},
#  {'calories': '500',
#   'category': 'Sides',
#   'fat': '29',
#   'carbs': '32',
#   'name': 'BK® Chicken Fries (12 pc)',
#   'restaurant': 'Burger King'},
#  {'calories': '540',
#   'category': 'French Fries',
#   'fat': '27',
#   'carbs': '69',
#   'name': 'French Fries - large (Salted)',
#   'restaurant': 'Burger King'},
#  {'calories': '270',
#   'category': 'Salads',
#   'fat': '23',
#   'carbs': '15',
#   'name': "Ken's® Honey Mustard Dressing (2 oz)",
#   'restaurant': 'Burger King'},
#  {'calories': '1310',
#   'category': 'Breakfast',
#   'fat': '72',
#   'carbs': '134',
#   'name': 'BK™ Ultimate Breakfast Platter',
#   'restaurant': 'Burger King'},
#  {'calories': '440',
#   'category': 'Breakfast',
#   'fat': '25',
#   'carbs': '27',
#   'name': "Double Croissan'wich™ w/ Bacon, Egg, & Cheese",
#   'restaurant': 'Burger King'},
#  {'calories': '670',
#   'category': 'Breakfast',
#   'fat': '34',
#   'carbs': '78',
#   'name': 'Pancake Platter w/ Sausage & 1 oz Breakfast Syrup',
#   'restaurant': 'Burger King'},
#  {'calories': '400',
#   'category': 'Breakfast',
#   'fat': '18',
#   'carbs': '52',
#   'name': 'Cini‐minis (4 minis)',
#   'restaurant': 'Burger King'},
#  {'calories': '650',
#   'category': 'Breakfast',
#   'fat': '38',
#   'carbs': '50',
#   'name': 'Biscuit‐ w/ Breakfast Steak (Country Fried Steak)',
#   'restaurant': 'Burger King'},
#  {'calories': '280',
#   'category': 'Desserts',
#   'fat': '7',
#   'carbs': '50',
#   'name': 'Chocolate Fudge Sundae',
#   'restaurant': 'Burger King'},
#  {'calories': '660',
#   'category': 'Shakes',
#   'fat': '17',
#   'carbs': '114',
#   'name': 'Vanilla Milk Shake',
#   'restaurant': 'Burger King'},
#  {'calories': '400',
#   'category': 'Burgers',
#   'fat': '23',
#   'carbs': '39',
#   'name': 'BK Toppers™ Western BBQ Cheeseburger',
#   'restaurant': 'Burger King'},
#  {'calories': '760',
#   'category': 'Sandwiches',
#   'fat': '47',
#   'carbs': '53',
#   'name': 'Whopper® Sandwich with Cheese',
#   'restaurant': 'Burger King'},
#  {'calories': '800',
#   'category': 'Sandwiches',
#   'fat': '51',
#   'carbs': '50',
#   'name': 'Texas Whopper® Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '360',
#   'category': 'Burgers',
#   'fat': '18',
#   'carbs': '28',
#   'name': 'Double Hamburger',
#   'restaurant': 'Burger King'},
#  {'calories': '360',
#   'category': 'Sandwiches',
#   'fat': '7',
#   'carbs': '40',
#   'name': 'Tendergrill® Chicken Sandwich w/o Mayo',
#   'restaurant': 'Burger King'},
#  {'calories': '190',
#   'category': 'Chicken',
#   'fat': '11',
#   'carbs': '10',
#   'name': 'Chicken Tenders® (4 pc)',
#   'restaurant': 'Burger King'},
#  {'calories': '810',
#   'category': 'Sandwiches',
#   'fat': '42',
#   'carbs': '78',
#   'name': 'Country Pork Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '280',
#   'category': 'Sides',
#   'fat': '15',
#   'carbs': '24',
#   'name': 'Mozzarella Sticks (4 pc)',
#   'restaurant': 'Burger King'},
#  {'calories': '60',
#   'category': 'Salads',
#   'fat': '2',
#   'carbs': '9',
#   'name': 'Garlic Parmesan Croutons',
#   'restaurant': 'Burger King'},
#  {'calories': '810',
#   'category': 'Breakfast',
#   'fat': '54',
#   'carbs': '57',
#   'name': 'BK™ Breakfast Platter',
#   'restaurant': 'Burger King'},
#  {'calories': '570',
#   'category': 'Breakfast',
#   'fat': '37',
#   'carbs': '28',
#   'name': "Double Croissan'wich™ w/ Sausage, Bacon, Egg, & Cheese",
#   'restaurant': 'Burger King'},
#  {'calories': '160',
#   'category': 'Breakfast',
#   'fat': '12',
#   'carbs': '3',
#   'name': 'Side of Eggs',
#   'restaurant': 'Burger King'},
#  {'calories': '90',
#   'category': 'Breakfast',
#   'fat': '0',
#   'carbs': '22',
#   'name': 'Vanilla Icing',
#   'restaurant': 'Burger King'},
#  {'calories': '470',
#   'category': 'Breakfast',
#   'fat': '26',
#   'carbs': '33',
#   'name': 'Biscuit‐ w/ Country Ham (1 sl) & Egg and Cheese',
#   'restaurant': 'Burger King'},
#  {'calories': '190',
#   'category': 'Desserts',
#   'fat': '4',
#   'carbs': '35',
#   'name': 'Strawberry Sundae',
#   'restaurant': 'Burger King'},
#  {'calories': '850',
#   'category': 'Shakes',
#   'fat': '20',
#   'carbs': '152',
#   'name': 'Vanilla Milk Shake',
#   'restaurant': 'Burger King'},
#  {'calories': '410',
#   'category': 'Burgers',
#   'fat': '27',
#   'carbs': '27',
#   'name': 'BK Toppers™ Mushroom and Swiss',
#   'restaurant': 'Burger King'},
#  {'calories': '600',
#   'category': 'Sandwiches',
#   'fat': '30',
#   'carbs': '53',
#   'name': 'Whopper® Sandwich with Cheese w/o Mayo',
#   'restaurant': 'Burger King'},
#  {'calories': '1040',
#   'category': 'Sandwiches',
#   'fat': '69',
#   'carbs': '50',
#   'name': 'Texas Double Whopper® Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '450',
#   'category': 'Burgers',
#   'fat': '26',
#   'carbs': '29',
#   'name': 'Double Cheeseburger',
#   'restaurant': 'Burger King'},
#  {'calories': '750',
#   'category': 'Sandwiches',
#   'fat': '45',
#   'carbs': '58',
#   'name': 'Tendercrisp® Chicken Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '290',
#   'category': 'Chicken',
#   'fat': '17',
#   'carbs': '15',
#   'name': 'Chicken Tenders® (6 pc)',
#   'restaurant': 'Burger King'},
#  {'calories': '590',
#   'category': 'Sandwiches',
#   'fat': '31',
#   'carbs': '57',
#   'name': 'BK Big Fish® Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '50',
#   'category': 'Sides',
#   'fat': '0',
#   'carbs': '13',
#   'name': "Motts'® Harvest Plus Applesauce",
#   'restaurant': 'Burger King'},
#  {'calories': '290',
#   'category': 'Salads',
#   'fat': '12',
#   'carbs': '8',
#   'name': 'Tendergrill™ Chicken Garden Salad',
#   'restaurant': 'Burger King'},
#  {'calories': '270',
#   'category': 'Breakfast',
#   'fat': '4',
#   'carbs': '55',
#   'name': 'Quaker® Oatmeal Maple and Brown Sugar Flavor',
#   'restaurant': 'Burger King'},
#  {'calories': '480',
#   'category': 'Breakfast',
#   'fat': '23',
#   'carbs': '41',
#   'name': 'BK™ Breakfast Ciabatta Club Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '440',
#   'category': 'Breakfast',
#   'fat': '24',
#   'carbs': '28',
#   'name': "Double Croissan'wich™ w/ Ham, Bacon, Egg, & Cheese",
#   'restaurant': 'Burger King'},
#  {'calories': '230',
#   'category': 'Breakfast',
#   'fat': '11',
#   'carbs': '29',
#   'name': 'French Toast Sticks (3 piece)',
#   'restaurant': 'Burger King'},
#  {'calories': '440',
#   'category': 'Breakfast',
#   'fat': '29',
#   'carbs': '25',
#   'name': 'BK™ Breakfast Burrito ‐ Sausage, Egg, Cheese & Salsa',
#   'restaurant': 'Burger King'},
#  {'calories': '280',
#   'category': 'Desserts',
#   'fat': '5',
#   'carbs': '54',
#   'name': 'Peach Granola Sundae',
#   'restaurant': 'Burger King'},
#  {'calories': '420',
#   'category': 'Shakes',
#   'fat': '8',
#   'carbs': '81',
#   'name': 'Chocolate Milk Shake',
#   'restaurant': 'Burger King'},
#  {'calories': '300',
#   'category': 'Desserts',
#   'fat': '16',
#   'carbs': '35',
#   'name': 'Strawberry Swirl Cheesecake',
#   'restaurant': 'Burger King'},
#  {'calories': '900',
#   'category': 'Sandwiches',
#   'fat': '57',
#   'carbs': '51',
#   'name': 'Double Whopper® Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '1270',
#   'category': 'Sandwiches',
#   'fat': '86',
#   'carbs': '50',
#   'name': 'Texas Triple Whopper® Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '350',
#   'category': 'Burgers',
#   'fat': '17',
#   'carbs': '37',
#   'name': 'Rodeo Cheeseburger',
#   'restaurant': 'Burger King'},
#  {'calories': '540',
#   'category': 'Sandwiches',
#   'fat': '21',
#   'carbs': '57',
#   'name': 'Tendercrisp® Chicken Sandwich w/o Mayo',
#   'restaurant': 'Burger King'},
#  {'calories': '380',
#   'category': 'Chicken',
#   'fat': '22',
#   'carbs': '20',
#   'name': 'Chicken Tenders® (8 pc)',
#   'restaurant': 'Burger King'},
#  {'calories': '410',
#   'category': 'Sandwiches',
#   'fat': '12',
#   'carbs': '53',
#   'name': 'BK Big Fish® Sandwich w/o Tartar Sauce',
#   'restaurant': 'Burger King'},
#  {'calories': '150',
#   'category': 'Sides',
#   'fat': '8',
#   'carbs': '17',
#   'name': 'Onion Rings - value',
#   'restaurant': 'Burger King'},
#  {'calories': '470',
#   'category': 'Salads',
#   'fat': '26',
#   'carbs': '26',
#   'name': 'Tendercrisp® Chicken Garden Salad',
#   'restaurant': 'Burger King'},
#  {'calories': '760',
#   'category': 'Breakfast',
#   'fat': '44',
#   'carbs': '44',
#   'name': 'Enormous Omelet Sandwich',
#   'restaurant': 'Burger King'},
#  {'calories': '570',
#   'category': 'Breakfast',
#   'fat': '35',
#   'carbs': '28',
#   'name': "Double Croissan'wich™ w/ Ham, Sausage, Egg, & Cheese",
#   'restaurant': 'Burger King'},
#  {'calories': '380',
#   'category': 'Breakfast',
#   'fat': '18',
#   'carbs': '49',
#   'name': 'French Toast Sticks (5 piece)',
#   'restaurant': 'Burger King'},
#  {'calories': '320',
#   'category': 'Breakfast',
#   'fat': '17',
#   'carbs': '29',
#   'name': 'BK™ Breakfast Burrito ‐ Potato, Egg, Cheese, & Salsa',
#   'restaurant': 'Burger King'},
#  {'calories': '440',
#   'category': 'Desserts',
#   'fat': '12',
#   'carbs': '77',
#   'name': 'Oreo® Sundae',
#   'restaurant': 'Burger King'},
#  {'calories': '690',
#   'category': 'Shakes',
#   'fat': '18',
#   'carbs': '121',
#   'name': 'Chocolate Milk Shake',
#   'restaurant': 'Burger King'},
#  {'calories': '110',
#   'category': 'Drinks',
#   'fat': '0',
#   'carbs': '31',
#   'name': 'Fanta Cherry frozen concentrated beverage',
#   'restaurant': 'Burger King'},
#  {'calories': '460',
#   'category': 'Entrees',
#   'fat': '21',
#   'carbs': '51',
#   'name': 'Bite Size Shrimp ',
#   'restaurant': "Captain D's"},
#  {'calories': '680',
#   'category': 'Sandwiches',
#   'fat': '33',
#   'carbs': '69',
#   'name': 'Chicken Ranch Sandwich ',
#   'restaurant': "Captain D's"},
#  {'calories': '170',
#   'category': 'Sides',
#   'fat': '7',
#   'carbs': '25',
#   'name': 'Roasted Red Potatoes ',
#   'restaurant': "Captain D's"},
#  {'calories': '230',
#   'category': 'Sides',
#   'fat': '14',
#   'carbs': '23',
#   'name': 'Fried Okra ',
#   'restaurant': "Captain D's"},
#  {'calories': '320',
#   'category': 'Desserts',
#   'fat': '14',
#   'carbs': '43',
#   'name': 'Pineapple Cream Cheese Pie ',
#   'restaurant': "Captain D's"},
#  {'calories': '182',
#   'category': 'Entrees',
#   'fat': '12',
#   'carbs': '8',
#   'name': 'Batter‐Dipped Fish ',
#   'restaurant': "Captain D's"},
#  {'calories': '321',
#   'category': 'Entrees',
#   'fat': '19',
#   'carbs': '27',
#   'name': 'Coconut Shrimp ',
#   'restaurant': "Captain D's"},
#  {'calories': '520',
#   'category': 'Sandwiches',
#   'fat': '18',
#   'carbs': '48',
#   'name': 'Wild Alaskan Salmon Sandwich ',
#   'restaurant': "Captain D's"},
#  {'calories': '200',
#   'category': 'Sides',
#   'fat': '13',
#   'carbs': '18',
#   'name': 'Hush Puppies (2) ',
#   'restaurant': "Captain D's"},
#  {'calories': '60',
#   'category': 'Sides',
#   'fat': '0',
#   'carbs': '13',
#   'name': 'Ginger Teriyaki Sauce ',
#   'restaurant': "Captain D's"},
#  {'calories': '195',
#   'category': 'Entrees',
#   'fat': '10',
#   'carbs': '14',
#   'name': 'Country Style Fish ',
#   'restaurant': "Captain D's"},
#  {'calories': '100',
#   'category': 'Entrees',
#   'fat': '5',
#   'carbs': '9',
#   'name': 'Stuffed Crab Shell ',
#   'restaurant': "Captain D's"},
#  {'calories': '177',
#   'category': 'Salads',
#   'fat': '1',
#   'carbs': '8',
#   'name': 'Wild Alaskan Salmon Salad ',
#   'restaurant': "Captain D's"},
#  {'calories': '160',
#   'category': 'Sides',
#   'fat': '12',
#   'carbs': '11',
#   'name': 'Cracklins ',
#   'restaurant': "Captain D's"},
#  {'calories': '120',
#   'category': 'Sides',
#   'fat': '10',
#   'carbs': '5',
#   'name': 'Scampi Butter Sauce ',
#   'restaurant': "Captain D's"},
#  {'calories': '130',
#   'category': 'Entrees',
#   'fat': '3',
#   'carbs': '1',
#   'name': 'Seasoned Tilapia ',
#   'restaurant': "Captain D's"},
#  {'calories': '170',
#   'category': 'Entrees',
#   'fat': '10',
#   'carbs': '11',
#   'name': 'Chicken Tender ',
#   'restaurant': "Captain D's"},
#  {'calories': '14',
#   'category': 'Sides',
#   'fat': '0',
#   'carbs': '2',
#   'name': 'Side Salad ',
#   'restaurant': "Captain D's"},
#  {'calories': '150',
#   'category': 'Sides',
#   'fat': '6',
#   'carbs': '21',
#   'name': 'Breadstick ',
#   'restaurant': "Captain D's"},
#  {'calories': '300',
#   'category': 'Desserts',
#   'fat': '11',
#   'carbs': '49',
#   'name': 'Chocolate Cake ',
#   'restaurant': "Captain D's"},
#  {'calories': '154',
#   'category': 'Entrees',
#   'fat': '6',
#   'carbs': '0',
#   'name': 'Premium Shrimp ',
#   'restaurant': "Captain D's"},
#  {'calories': '642',
#   'category': 'Sandwiches',
#   'fat': '38',
#   'carbs': '56',
#   'name': 'Great Little Fish Sandwich ',
#   'restaurant': "Captain D's"},
#  {'calories': '310',
#   'category': 'Sides',
#   'fat': '15',
#   'carbs': '38',
#   'name': 'French Fries ',
#   'restaurant': "Captain D's"},
#  {'calories': '160',
#   'category': 'Sides',
#   'fat': '1',
#   'carbs': '35',
#   'name': 'Seasoned Rice ',
#   'restaurant': "Captain D's"},
#  {'calories': '410',
#   'category': 'Desserts',
#   'fat': '27',
#   'carbs': '35',
#   'name': 'Cheesecake ',
#   'restaurant': "Captain D's"},
#  {'calories': '50',
#   'category': 'Entrees',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'Shrimp Skewers ',
#   'restaurant': "Captain D's"},
#  {'calories': '744',
#   'category': 'Sandwiches',
#   'fat': '41',
#   'carbs': '63',
#   'name': 'Classic Fish Sandwich ',
#   'restaurant': "Captain D's"},
#  {'calories': '160',
#   'category': 'Sides',
#   'fat': '7',
#   'carbs': '17',
#   'name': 'Macaroni & Cheese ',
#   'restaurant': "Captain D's"},
#  {'calories': '155',
#   'category': 'Sides',
#   'fat': '7',
#   'carbs': '20',
#   'name': 'Jalapeno Poppers ',
#   'restaurant': "Captain D's"},
#  {'calories': '470',
#   'category': 'Desserts',
#   'fat': '26',
#   'carbs': '56',
#   'name': 'Pecan Pie ',
#   'restaurant': "Captain D's"},
#  {'calories': '28',
#   'category': 'Entrees',
#   'fat': '0',
#   'carbs': '0',
#   'name': 'Scampi Shrimp ',
#   'restaurant': "Captain D's"},
#  {'calories': '1008',
#   'category': 'Sandwiches',
#   'fat': '50',
#   'carbs': '81',
#   'name': 'The Captain ',
#   'restaurant': "Captain D's"},
#  {'calories': '170',
#   'category': 'Sides',
#   'fat': '12',
#   'carbs': '13',
#   'name': 'Cole Slaw ',
#   'restaurant': "Captain D's"},
#  {'calories': '220',
#   'category': 'Sides',
#   'fat': '12',
#   'carbs': '16',
#   'name': 'Cheese Sticks ',
#   'restaurant': "Captain D's"},
#  {'calories': '430',
#   'category': 'Desserts',
#   'fat': '26',
#   'carbs': '45',
#   'name': 'Cheesecake with Strawberries ',
#   'restaurant': "Captain D's"},
#  {'calories': '213',
#   'category': 'Entrees',
#   'fat': '13',
#   'carbs': '12',
#   'name': 'Fried Flounder ',
#   'restaurant': "Captain D's"},
#  {'calories': '320',
#   'category': 'Entrees',
#   'fat': '18',
#   'carbs': '31',
#   'name': 'Oysters ',
#   'restaurant': "Captain D's"},
#  {'calories': '267',
#   'category': 'Salads',
#   'fat': '10',
#   'carbs': '33',
#   'name': 'Bite Size Shrimp Salad ',
#   'restaurant': "Captain D's"},
#  {'calories': '190',
#   'category': 'Sides',
#   'fat': '2',
#   'carbs': '37',
#   'name': 'Corn on the Cob ',
#   'restaurant': "Captain D's"},
#  {'calories': '100',
#   'category': 'Sides',
#   'fat': '0',
#   'carbs': '25',
#   'name': 'Sweet Chili Sauce ',
#   'restaurant': "Captain D's"},
#  {'calories': '105',
#   'category': 'Entrees',
#   'fat': '6',
#   'carbs': '6',
#   'name': 'Catfish ',
#   'restaurant': "Captain D's"},
#  {'calories': '770',
#   'category': 'Entrees',
#   'fat': '47',
#   'carbs': '64',
#   'name': '1/2 LB Clams ',
#   'restaurant': "Captain D's"},
#  {'calories': '207',
#   'category': 'Salads',
#   'fat': '10',
#   'carbs': '18',
#   'name': 'Fried Chicken Salad ',
#   'restaurant': "Captain D's"},
#  ...]

# %% [markdown]
# ### Step 4: Create a pandas DataFrame from your list of foods
#
# **Note**: Your DataFrame should have 5,131(?) rows

# %%
foods = pd.DataFrame(foods)
foods
# Out:
#      calories      category fat carbs                                name  \
# 0         760       Burgers  45    45  Original Bacon Double Cheeseburger
# 1         340       Entrees  20    26                   Coney (Chili) Dog
# 2         370  French Fries  15    49                         Chili Fries
# 3         670        Shakes  29    90        Strawberry Milkshake (small)
# 4         820        Shakes  18   150       A&W® Root Beer Freeze (large)
# ...       ...           ...  ..   ...                                 ...
# 5126      200        Shakes   5    32      Jr. Original Chocolate Frosty™
# 5127      260         Wraps  10    25             Grilled Chicken Go Wrap
# 5128      670    Sandwiches  32    57           Asiago Ranch Chicken Club
# 5129      330         Wraps  16    30               Spicy Chicken Go Wrap
# 5130      780        Shakes  15   149      Large Strawberry Frosty™ Shake
#
#            restaurant
# 0     A&W Restaurants
# 1     A&W Restaurants
# 2     A&W Restaurants
# 3     A&W Restaurants
# 4     A&W Restaurants
# ...               ...
# 5126          Wendy's
# 5127          Wendy's
# 5128          Wendy's
# 5129          Wendy's
# 5130          Wendy's
#
# [5131 rows x 6 columns]

# %% [markdown]
# ### Step 5: Export to csv
#
# **Note:** Don't export the index column from your DataFrame

# %%
foods.to_csv('restaurants_scraping.csv', index=False, header=True)

# %%
df = pd.read_csv('restaurants_scraping.csv')
df
# Out:
#       calories      category  fat  carbs                                name  \
# 0          760       Burgers   45     45  Original Bacon Double Cheeseburger
# 1          340       Entrees   20     26                   Coney (Chili) Dog
# 2          370  French Fries   15     49                         Chili Fries
# 3          670        Shakes   29     90        Strawberry Milkshake (small)
# 4          820        Shakes   18    150       A&W® Root Beer Freeze (large)
# ...        ...           ...  ...    ...                                 ...
# 5126       200        Shakes    5     32      Jr. Original Chocolate Frosty™
# 5127       260         Wraps   10     25             Grilled Chicken Go Wrap
# 5128       670    Sandwiches   32     57           Asiago Ranch Chicken Club
# 5129       330         Wraps   16     30               Spicy Chicken Go Wrap
# 5130       780        Shakes   15    149      Large Strawberry Frosty™ Shake
#
#            restaurant
# 0     A&W Restaurants
# 1     A&W Restaurants
# 2     A&W Restaurants
# 3     A&W Restaurants
# 4     A&W Restaurants
# ...               ...
# 5126          Wendy's
# 5127          Wendy's
# 5128          Wendy's
# 5129          Wendy's
# 5130          Wendy's
#
# [5131 rows x 6 columns]
