# %% [raw]
# Q1: This is a TSV. What would you do with the missing values and why?
#
# carat    color
# 12       yellow
# 24
# 28
# 12       blue
# 24
# 23       pink
# 20       yellow
#
# A: MCAR. Drop the missing values. Color of the diamond does not necessarily correspond to its carat and therefore and deduction or
#
# A (JR): Default is transparent. Maybe should be inputted as missing value. NOT DROP!!!!!!!
#
#
# Q2: Same question, diff dataset.
#
# price       sqft     num_bedrooms
# 120980      129
# 1980922     182      1
# 2009012     819      2
# 1081029     912      2
# 2828280     1910     4
# 1293280              3
#
# A: MAR. Sqft could reasonably be deduced by imput.
#
# But num_bedrooms may not be true. It could be a studio or a 1br.
#
# A (JR): Missing num_bedrooms is probably studio. Missing sqft is dealt with (maybe) deduction, but maybe drop.
#
#
# Q3: Same quesion, diff dataset.
#
# disease       male         BMI      age
# yes                        25       40
#                            20       14
# yes           yes                   50
# yes                        21       15
#                            20       34
# yes                        29       60
#
# A: Input disease = no ifnull
# Input male = no ifnull
# BMI row should just be dropped since no reasonable deduction (only male data)
#
# A (JR): If only 1 row, drop possible. If more, then maybe it's a NMAR cause people with high BMI does not answer.
#
#
# Q4: State type of missing data.
#
# 4i. Survey of whether people experiencing depression are more likely to use drugs. 100 respondents, 20 did not answer.
# A: NMAR. More likely for someone who used drugs not to answer for fear of retribution.
#
# A (JR): NMAR. Missingness may be causated by drug use. Drug use ==> Missingness
#
# 4ii. Measure BP as variable of Cholesterol. 50 total samples, 2 corrupted.
# A: MCAR. Assuming that no tampering was done, the corruption was completely random.
#
# A (JR): MCAR. Unlikely for specifically targeted corruption.
#
# 4iii. Studying student exam scores as function of stress at home. 30 schools, 10 scores each. Time of study end, 2 schools fail to submit questionnaires
# A: MAR. Not completely because they are 'grouped' in one school, but taken as a whole, the missing data may not be systematically different.
#
# A (JR): MAR.
#
# 4iv. 1% of all rows of data is corrupted.
# A: Depends on the corruption. If corruption is staggered, then MCAR. If only top/bottom 1% rows, may be NMAR.
#
# A (JR): Most likely to be scattered around. But should check.
