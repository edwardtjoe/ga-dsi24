# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The United Nation's Universal Declaration of Human Rights states that "Everyone has the right to education. Education shall be free, at least in the...fundamental stages." In the US, public education is free all through high school, after which students take the ACT and/or SAT for higher education. While public K-12 are free, there is a disparity between exam participation rates and its by state, which critics of standardized exams attribute to various biases in the exam's creation.
#
# One argument for the presence of subjectivity is that exam-takers from higher income families can afford to retake the test which has been shown to improve scores ([*source*](https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html)). Higher incomes also allow higher tax collections, which enables public schools to afford more and better quality educators leading to higher quality education. As such, higher incomes beget better education, which in turn begets greater prospects of entering better tertiary education and creates a pathway to greater future earnings potential.
#
# Therefore, should more federal education spending be allocated to states with lower examination participation and scores to supplement median income? We explore the correlation between median household levels and standardized exam scores. Does a higher median household income level of a state suggest a higher examination participation and score in the state?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# Public education spending is a highly debated issue with Democrats and Republicans holding opposing views. In general, Democrats want much higher public school spending fueled by higher tax rates to improve the nation’s overall education standards, while Republicans are in favor of less public education spending and lower taxes to allow families the freedom to choice in education spending ([*source*](https://www.ascd.org/blogs/what-the-democrats-and-republicans-stand-for-on-education-excerpts-from-party-platforms)).
#
# One of the points of the debate centers around the federal government’s allocation of funding by state. A 2015 research report found a sizable disparity between the highest and lowest funding per student, with students in New York having access to nearly 3 times the amount of funding as compared to Idaho (USD 18,719 vs USD 6,277 per pupil) ([*source*](https://edlawcenter.org/assets/files/pdfs/publications/Is_School_Funding_Fair_7th_Editi.pdf)). If student access to funding correlates with higher scores in the standardized exams, should more federal funding be allocated to states with lower median income level to supplement private household education spending?

# %% [markdown]
# ### Data

# %% [markdown]
# Datasets used:
#
# 1. [`act_2017.csv`](../data/act_2017.csv): 2017 ACT Results by State
#
#
# 2. [`act_2018.csv`](../data/act_2018.csv): 2018 ACT Results by State
#
#
# 3. [`sat_2017.csv`](../data/sat_2017.csv)sat_2017.csv: 2017 SAT Results by State
#
#
# 4. [`sat_2018.csv`](../data/sat_2018.csv): 2018 SAT Results by State
#
#
# 5. [`Median_Income_2017_2018.csv`](../data/Median_Income_2017_2018.csv): 2017 and 2018 Median Household Income by State
# ([*source*](https://www.census.gov/data/tables/time-series/demo/income-poverty/historical-income-households.html))
#
#
# - ACT and SAT results include: participation, individual subjects (if availble) and composite or total scores.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Much research has been done on the correlation and causation of income and higher ACT and SAT examination scores. In a 2013 research paper titled "Race, Poverty and SAT Scores" by Dixon-Roman et al, poverty was linked to lower SAT scores, and this disparity is more prevalent in Black exam-takers as compared to their White peers ([*source*](https://www.researchgate.net/publication/280232788_Race_Poverty_and_SAT_Scores_Modeling_the_Influences_of_Family_Income_on_Black_and_White_High_School_Students%27_SAT_Performance)). Another research by Baker et al. from Rutgers University suggests a prominent link between low levels of student poverty and higher rates of academic achievement ([*source*]( https://drive.google.com/file/d/1cm6Jkm6ktUT3SQplzDFjJIy3G3iLWOtJ/view)). These conclusions present a similar picture: economic status affects education achievements.
#
# As a whole, 90% of all K-12 students in the United States are enrolled in a public school ([*source*](https://research.com/education/american-school-statistics)). While public schools are mainly funded by state and local taxes, federal funding is playing an increasingly larger role in education spending ([*source*](https://www2.ed.gov/about/overview/fed/10facts/index.html)). Federal funding today accounts for roughly 5-10% of total education spending by state, depending on the amount of local and state tax allocated towards education. Due to the disproportionate amounts of funding in states and localities, it may be more equitable to increase federal funding be to states with lower median household income. This project aims to assess whether disproportionate federal spending on education to supplement state and local funding on education based on household incomes merits discussion.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

numbers_list = [10, 12, 20, 22, 34, 40]

def find_mean(list_of_numbers):
    count = 0
    total_sum = 0
    for number in list_of_numbers:
        total_sum += number
        count += 1
    return total_sum / count

find_mean(numbers_list)
# Out:
# 23.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

numbers_list = [10, 12, 20, 22, 34, 40]

def find_std(list_of_numbers):
    list_mean = find_mean(list_of_numbers)
    sum_std = 0
    for number in list_of_numbers:
        sum_std += ( 1 / len(list_of_numbers) ) * ((number - list_mean) ** 2)
    result = sum_std ** (0.5)
    return result
        
find_std(numbers_list)
# Out:
# 10.878112581387146

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

string_list = ["50%", "30.5%", "42.1%"]

def decimal_approx(list_of_strings):
    result = []
    for i in list_of_strings:
        result.append(round(float(i.strip("%"))/100, 3))
    return result

decimal_approx(string_list)
# Out:
# [0.5, 0.305, 0.421]

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Function to edit state names.
# Replaces space into underscore
# Lowecases all letters

def name_edits(list_state_name):
    for name in list_state_name:
        list_state_name = [name.lower().replace(" ", "_") for name in list_state_name]
    return list_state_name

# %%
# Code:
# Data used are: 
act_2017 = pd.read_csv("../data/act_2017.csv") # rows: 52, cols: 7. Has National
act_2018 = pd.read_csv("../data/act_2018.csv") # rows: 52, cols: 3. Has extra Maine
sat_2017 = pd.read_csv("../data/sat_2017.csv") # rows: 51, cols: 5
sat_2018 = pd.read_csv("../data/sat_2018.csv") # rows: 51, cols: 5

# when:
# col: 3 = State, Participation, Composite
# col: 7 = col 3 + English, Math, Reading, Science
# col: 5 = State, Participation, Evidence-Based Reading and Writing, Math, Total

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
# Note: Cleaning act_2017 data:
act_2017.info()

# 1. First, find out why composite is an object.
# Then, find and replace string with number
for value in act_2017["Composite"]:
    try:
        float(value)
    except:
        print(value, "is a string")
        print(act_2017.loc[act_2017["Composite"] == value])
        
# 2. Change type from object to float
act_2017.loc[act_2017["State"] == "Wyoming", "Composite"] = 20.2
act_2017["Composite"] = pd.to_numeric(act_2017["Composite"])

# 3. Rename to lowercase and shorter name. Remember to describe later on.
act_2017.rename(columns={"State": "state",
                         "Participation": "act_2017_part",
                         "English": "act_2017_eng",
                         "Math": "act_2017_math",
                         "Reading": "act_2017_read",
                         "Science": "act_2017_sci",
                         "Composite": "act_2017_comp"
                        }, inplace=True)

# 4. Change participation into floats using the function made from Q1(b)
act_2017["act_2017_part"] = decimal_approx(act_2017["act_2017_part"])

# 5. Renaming states into lowercase and replacing spaces to underscore
# using function above
act_2017["state"] = name_edits(act_2017["state"])

# 6. Maryland's science score is an anomaly, 
# therefore we derive it from the available data.
act_2017.loc[act_2017["state"] == "maryland", "act_2017_sci"]
act_2017.loc[act_2017["state"] == "maryland", "act_2017_sci"] = \
    act_2017.loc[act_2017["state"] == "maryland", "act_2017_comp"] * 4 \
    - act_2017.loc[act_2017["state"] == "maryland", "act_2017_read"] \
    - act_2017.loc[act_2017["state"] == "maryland", "act_2017_math"] \
    - act_2017.loc[act_2017["state"] == "maryland", "act_2017_eng"]

act_2017.info()
act_2017.head()
act_2017.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB
# 20.2x is a string
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.2x
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
# ...

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# Note: Cleaning act_2018 data:

act_2018.info()

# 1. Rename to lowercase and shorter name. Remember to describe later on.
act_2018.rename(columns={"State": "state",
                         "Participation": "act_2018_part",
                         "Composite": "act_2018_comp"
                        }, inplace=True)

# 2. Change participation into floats using the function made from Q1(b)
act_2018["act_2018_part"] = decimal_approx(act_2018["act_2018_part"])

# 3. Renaming states into lowercase and replacing spaces to underscore
# using function above
act_2018["state"] = name_edits(act_2018["state"])

# 4. There are two "Maine" entries. Need to drop one, then reset_index.
# Remember to inplace=True and drop=True to avoid duplicating
act_2018["state"].value_counts().sort_values(ascending=False).head()
act_2018.drop(index=19, inplace=True)
act_2018.reset_index(drop=True, inplace=True)

# 5. Checking if data is sufficiently clean
act_2018.info()
act_2018.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   act_2018_part  51 non-null     float64
#  2   act_2018_comp  51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB
#         state  act_2018_part  act_2018_comp
# 0     alabama           1.00           19.1
# 1      alaska           0.33           20.8
# 2     arizona           0.66           19.2
# ...

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# Note: Cleaning sat_2017 data:

sat_2017.info()

# 1. Rename to lowercase and shorter name. Remember to describe later on.
sat_2017.rename(columns={"State": "state",
                         "Participation": "sat_2017_part",
                         "Total": "sat_2017_total",
                         "Evidence-Based Reading and Writing": "sat_2017_read_write",
                         "Math": "sat_2017_math"
                        }, inplace=True)

# 2. Renaming states into lowercase and replacing spaces to underscore
# using function above
sat_2017["state"] = name_edits(sat_2017["state"])

# 3. Change participation into floats using the function made from Q1(b)
sat_2017["sat_2017_part"] = decimal_approx(sat_2017["sat_2017_part"])

# 4. Maryland's math data is an anomaly. Let's derive it from the Total
sat_2017["sat_2017_math"].sort_values(ascending=True) 
sat_2017.loc[sat_2017["sat_2017_math"] == 52, "state"] # Find state with math = 52
sat_2017.loc[sat_2017["state"] == "maryland", "sat_2017_math"] = \
    sat_2017.loc[sat_2017["state"] == "maryland", "sat_2017_total"]\
    - sat_2017.loc[sat_2017["state"] == "maryland", "sat_2017_read_write"]

# 5. Fixing Total
# Try summing up. 15 of the Totals are not the sum of R&W + Math.
sat_2017.loc[sat_2017["sat_2017_math"] + sat_2017["sat_2017_read_write"]\
             != sat_2017["sat_2017_total"], "state"]    # Found 15 Totals not matched
# Fixing total = math + read_write
sat_2017["sat_2017_total"] = sat_2017["sat_2017_math"] + sat_2017["sat_2017_read_write"]

# 6. Checking if data is sufficiently clean
sat_2017.head()
sat_2017.info()
sat_2017.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                51 non-null     object
#  1   sat_2017_part        51 non-null     float64
#  2   sat_2017_read_write  51 non-null     int64
# ...

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# Note: Cleaning sat_2017 data:

sat_2018.describe()

# 1. Rename to lowercase and shorter name. Remember to describe later on.
sat_2018.rename(columns={"State": "state",
                         "Participation": "sat_2018_part",
                         "Total": "sat_2018_total",
                         "Evidence-Based Reading and Writing": "sat_2018_read_write",
                         "Math": "sat_2018_math"
                        }, inplace=True)

# 2. Renaming states into lowercase and replacing spaces to underscore
# using function above
sat_2018["state"] = name_edits(sat_2018["state"])

# 3. Change participation into floats using the function made from Q1(b)
sat_2018["sat_2018_part"] = decimal_approx(sat_2018["sat_2018_part"])

# 4. Fixing Total
# Try summing up. 9 of the totals are not the sum of read_write + math.
# Fixing total = math + read_write
sat_2018.loc[sat_2018["sat_2018_math"] + sat_2018["sat_2018_read_write"]\
            != sat_2018["sat_2018_total"], "state"] # Found 9
sat_2018["sat_2018_total"] = sat_2018["sat_2018_math"] \
                           + sat_2018["sat_2018_read_write"]

# 5. Checking if data is sufficiently clean
sat_2018.info()
sat_2018.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                51 non-null     object
#  1   sat_2018_part        51 non-null     float64
#  2   sat_2018_read_write  51 non-null     int64
#  3   sat_2018_math        51 non-null     int64
#  4   sat_2018_total       51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
#         state  sat_2018_part  sat_2018_read_write  sat_2018_math  \
# 0     alabama           0.06                  595            571
# 1      alaska           0.43                  562            544
# 2     arizona           0.29                  577            572
# 3    arkansas           0.05                  592            576
# 4  california           0.60                  540            536
#
#    sat_2018_total
# 0            1166
# 1            1106
# ...

# %%
# act_2017.shape # 52, 7
# act_2018.shape # 51, 3
# sat_2017.shape # 51, 5
# sat_2018.shape # 51, 5

# %%
# Merging

df = act_2017.merge(act_2018, on = "state", how = "outer")\
             .merge(sat_2017, on = "state", how = "outer")\
             .merge(sat_2018, on = "state", how = "outer")
df.describe()
# Out:
#        act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# count      52.000000     52.000000      52.000000      52.000000
# mean        0.651538     20.919231      21.173077      22.001923
# std         0.318325      2.332132       1.963602       2.048672
# min         0.080000     16.300000      18.000000      18.100000
# 25%         0.310000     19.000000      19.400000      20.475000
# 50%         0.680000     20.550000      20.900000      21.700000
# 75%         1.000000     23.300000      23.100000      24.125000
# max         1.000000     25.500000      25.300000      26.000000
#
#        act_2017_sci  act_2017_comp  act_2018_part  act_2018_comp  \
# count     52.000000      52.000000      51.000000      51.000000
# mean      21.453846      21.509615       0.617255      21.496078
# std        1.737303       2.002083       0.340371       2.111583
# min       18.200000      17.800000       0.070000      17.700000
# ...

# %%
# Dropping national
df.drop(index=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# Clean external dataset and merge

med_inc = pd.read_csv("../data/Median_Income_2017_2018.csv")

# 1. Drop national average from list and reset index.
med_inc.drop(index=0, inplace=True)
med_inc.reset_index(drop=True, inplace=True)
med_inc.head()

# 2. Modify spaces into underscore and uppercase to lowercase.
med_inc["state"] = name_edits(med_inc["state"])

# 3. Rename column names for median income
med_inc.rename(columns={"2018": "2018_median_income",
                        "2017": "2017_median_income"},\
                        inplace=True)
display(med_inc.head(3))

# 4. Merging to df
df = df.merge(med_inc, on="state", how="outer")
# Out:
#      state  2018_median_income  2017_median_income
# 0  alabama               49936               50865
# 1   alaska               68734               77987
# 2  arizona               62283               59700

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT&SAT|US State
# |act_2017_part|float|ACT|2017 Participation Rate
# |act_2017_eng|float|ACT|2017 English Score
# |act_2017_math|float|ACT|2017 Math Score
# |act_2017_read|float|ACT|2017 Reading Score
# |act_2017_sci|float|ACT|2017 Science Score
# |act_2017_comp|float|ACT|2017 Composite Score
# |act_2018_part|float|ACT|2018 Participation Rate
# |act_2018_comp|float|ACT|2018 Composite Score
# |sat_2017_part|float|SAT|2017 Participation Rate
# |sat_2017_read_write|float|SAT|2017 Evidence-Based Reading and Writing Score
# |sat_2017_math|float|SAT|2017 Math Score
# |sat_2017_total|float|SAT|2017 Total Score
# |sat_2018_part|float|SAT|2018 Participation Rate
# |sat_2018_read_write|float|SAT|2018 Evidence-Based Reading and Writing Score
# |sat_2018_math|float|SAT|2018 Math Score
# |sat_2018_total|float|SAT|2018 Total Score
# |2017_median_income|float|N/A|2017 Median Annual Household Income by State
# |2018_median_income|float|N/A|2018 Median Annual Household Income by State
# |top_half_income_2017|float|N/A|Dummy Variable for States in the Top Half of Median Annual Income
# |top_half_income_2018|float|N/A|Dummy Variable for States in the Top Half of Median Annual Income

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                51 non-null     object
#  1   act_2017_part        51 non-null     float64
#  2   act_2017_eng         51 non-null     float64
#  3   act_2017_math        51 non-null     float64
#  4   act_2017_read        51 non-null     float64
#  5   act_2017_sci         51 non-null     float64
#  6   act_2017_comp        51 non-null     float64
#  7   act_2018_part        51 non-null     float64
#  8   act_2018_comp        51 non-null     float64
#  9   sat_2017_part        51 non-null     float64
#  10  sat_2017_read_write  51 non-null     float64
#  11  sat_2017_math        51 non-null     float64
#  12  sat_2017_total       51 non-null     float64
#  13  sat_2018_part        51 non-null     float64
#  14  sat_2018_read_write  51 non-null     float64
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sd = {i: find_std(df[i]) for i in df.columns[1:]}
sd
# Out:
# {'act_2017_part': 0.3182417575123181,
#  'act_2017_eng': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_read': 2.0469029314842646,
#  'act_2017_sci': 1.7361170088327353,
#  'act_2017_comp': 2.0007860815819893,
#  'act_2018_part': 0.33701735820410317,
#  'act_2018_comp': 2.0907790821411787,
#  'sat_2017_part': 0.3492907076664507,
#  'sat_2017_read_write': 45.21697020437867,
#  'sat_2017_math': 46.65713364485504,
#  'sat_2017_total': 91.5763904842162,
#  'sat_2018_part': 0.3694661922353942,
#  'sat_2018_read_write': 47.03460978357608,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.26114360945469,
#  '2018_median_income': 10261.12959300357,
#  '2017_median_income': 9581.892078655306}

# %%
#Code:
sd = ["stdev"]
column_names = ['act_2017_part', 'act_2017_eng', 'act_2017_math',
                'act_2017_read', 'act_2017_sci', 'act_2017_comp', 
                'act_2018_part', 'act_2018_comp', 'sat_2017_part', 
                'sat_2017_read_write', 'sat_2017_math', 'sat_2017_total',
                'sat_2018_part', 'sat_2018_read_write', 'sat_2018_math', 
                'sat_2018_total', '2018_median_income', '2017_median_income']

for i in column_names:
    sd.append(find_std(df[i]))


df.loc[len(df.index)] = sd

# df.drop(51, inplace=True)

df.tail(2)
# Out:
#       state  act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 50  wyoming       1.000000     19.400000      19.800000      20.800000
# 51    stdev       0.318242      2.330488       1.962462       2.046903
#
#     act_2017_sci  act_2017_comp  act_2018_part  act_2018_comp  sat_2017_part  \
# 50     20.600000      20.200000       1.000000      20.000000       0.030000
# 51      1.736117       2.000786       0.337017       2.090779       0.349291
#
#     sat_2017_read_write  sat_2017_math  sat_2017_total  sat_2018_part  \
# 50            626.00000     604.000000      1230.00000       0.030000
# 51             45.21697      46.657134        91.57639       0.369466
#
#     sat_2018_read_write  sat_2018_math  sat_2018_total  2018_median_income  \
# 50            633.00000     625.000000     1258.000000        62539.000000
# 51             47.03461      47.301946       93.261144        10261.129593
#
#     2017_median_income
# 50        59536.000000
# 51         9581.892079

# %%
# Code for Observation 1: Highest participation on act and sat for 2017 and 2018
display(df.sort_values(["act_2017_part", "act_2018_part"], ascending=False)\
        [["state", "act_2017_part", "act_2018_part"]].head(20))
display(df.sort_values(["sat_2017_part", "sat_2018_part"], ascending=False)\
        [["state", "sat_2017_part", "sat_2018_part"]].head(5))
display(df.sort_values("act_2017_part", ascending=False)\
        [["state", "act_2017_part"]].head(8))
display(df.sort_values("act_2018_part", ascending=False)\
        [["state", "act_2018_part"]].head(8))
display(df.sort_values("sat_2017_part", ascending=False)\
        [["state", "sat_2017_part"]].head(8))
display(df.sort_values("sat_2018_part", ascending=False)\
        [["state", "sat_2018_part"]].head(8))
# Out:
#              state  act_2017_part  act_2018_part
# 0          alabama           1.00           1.00
# 3         arkansas           1.00           1.00
# 17        kentucky           1.00           1.00
# 18       louisiana           1.00           1.00
# 24     mississippi           1.00           1.00
# 25        missouri           1.00           1.00
# 26         montana           1.00           1.00
# 28          nevada           1.00           1.00
# 33  north_carolina           1.00           1.00
# 36        oklahoma           1.00           1.00
# 40  south_carolina           1.00           1.00
# 42       tennessee           1.00           1.00
# 44            utah           1.00           1.00
# 49       wisconsin           1.00           1.00
# 50         wyoming           1.00           1.00
# 23       minnesota           1.00           0.99
# 5         colorado           1.00           0.30
# 34    north_dakota           0.98           0.98
# ...

# %% [markdown]
# Observation 1: Almost all states which have the highest ACT participation rate in 2017 have the highest ACT participation rate in 2018.
#
# 100% Participation in both 2017 and 2018 ACT: AL, AR, KY, LA, MS, MO, MT, NV, NC, OK, SC, TN, UT, WI, WY
#
# 100% Participation in both 2017 and 2018 SAT: CT, DE, MI

# %%
# Code for observation 2: States with highest mean composite or total in 2017 and 2018
df.sort_values("act_2017_comp", ascending=False)[["state", "act_2017_comp"]].head(5)
df.sort_values("act_2018_comp", ascending=False)[["state", "act_2018_comp"]].head(5)
df.sort_values("sat_2017_total", ascending=False)[["state", "sat_2017_total"]].head(5)
df.sort_values("sat_2018_total", ascending=False)[["state", "sat_2018_total"]].head(5)
# Out:
#            state  sat_2018_total
# 23     minnesota          1298.0
# 49     wisconsin          1294.0
# 34  north_dakota          1283.0
# 15          iowa          1265.0
# 16        kansas          1264.0

# %% [markdown]
# Observation 2: States with the highest composite score for 2017 ACT generally have the highest scores in 2018 ACT. This is also true for 2017 and 2018 SAT. In each examination, the top 4 out of 5 states with the highest score are the same.
#
# States which are in the top 5 of both years (2017 and 2018) are bolded below:
#
# act_2017_comp highest: **New Hampshire, Massachusetts, Connecticut**, Maine, **New York**
#
# act_2018_comp highest: **Connecticut, Massachusetts, New Hampshire, New York**, Michigan
#
# sat_2017_total highest: **Minnesota, Wisconsin, Iowa,** Missouri, **Kansas**
#
# sat_2018_total highest: **Minnesota, Wisconsin,** North Dakota, **Iowa, Kansas**

# %%
rate = 0.5
df.loc[(df["act_2017_part"] > rate) & (df["act_2018_part"] > rate)\
       & (df["sat_2017_part"] > rate) & (df["sat_2018_part"] > rate)]\
       [["state", "act_2017_part", "act_2018_part", "sat_2017_part", "sat_2018_part"]]
# Out:
#       state  act_2017_part  act_2018_part  sat_2017_part  sat_2018_part
# 9   florida           0.73           0.66           0.83           0.56
# 10  georgia           0.55           0.53           0.61           0.70
# 11   hawaii           0.90           0.89           0.55           0.56

# %% [markdown]
# ### <center>Observation: Only 3 states have participation over 50% for both ACT and SAT exams in both years: Florida, Georgia and Hawaii<center>

# %% [markdown]
# Observation 3: Only Florida, Georgia and Hawaii have more than 50% participation rates in both exams in both years.

# %%
df.sort_values(["act_2017_part"], ascending=True)[["state", "act_2017_part"]].head(7)
# Out:
#             state  act_2017_part
# 19          maine           0.08
# 29  new_hampshire           0.18
# 7        delaware           0.18
# 39   rhode_island           0.21
# 38   pennsylvania           0.23
# 20       maryland           0.28
# 21  massachusetts           0.29

# %%
df.sort_values(["act_2018_part"], ascending=True)[["state", "act_2018_part"]].head(7)
# Out:
#             state  act_2018_part
# 19          maine           0.07
# 39   rhode_island           0.15
# 29  new_hampshire           0.16
# 7        delaware           0.17
# 38   pennsylvania           0.20
# 22       michigan           0.22
# 45        vermont           0.24

# %%
df.sort_values(["sat_2017_part"], ascending=True)[["state", "sat_2017_part"]].head(7)
# Out:
#            state  sat_2017_part
# 34  north_dakota           0.02
# 24   mississippi           0.02
# 15          iowa           0.02
# 25      missouri           0.03
# 49     wisconsin           0.03
# 44          utah           0.03
# 3       arkansas           0.03

# %%
df.sort_values(["sat_2018_part"], ascending=True)[["state", "sat_2018_part"]].head(7)
# Out:
#            state  sat_2018_part
# 34  north_dakota           0.02
# 49     wisconsin           0.03
# 41  south_dakota           0.03
# 27      nebraska           0.03
# 50       wyoming           0.03
# 24   mississippi           0.03
# 15          iowa           0.03

# %% [markdown]
# ### <center>Observation: States with the lowest participation rates tend to repeat<center>
#
# <h3 align="center">Top 7 States with Lowest ACT Participation, Ranked</h3>
#
# |Year|<center>State<center>|Exam|Participation Rate||Year|State|Exam|Participation Rate|
# |----|-----|----|------------------|-|----|-----|----|------------------|
# |2017|<center>**Maine**<center>|ACT|<center>0.08<center>||2018|<center>**Maine**<center>|ACT|<center>0.07<center>|<center>0.07<center>|
# |2017|<center>**New Hampshire**<center>|ACT|<center>0.18<center>||2018|<center>**Rhode Island**<center>|ACT|<center>0.15<center>|
# |2017|<center>**Delaware**<center>|ACT|<center>0.18<center>||2018|<center>**New Hampshire**<center>|ACT|<center>0.16<center>|
# |2017|<center>**Rhode Island**<center>|ACT|<center>0.21<center>||2018|<center>**Delaware**<center>|ACT|<center>0.17<center>|
# |2017|<center>**Pennsylvania**<center>|ACT|<center>0.23<center>||2018|<center>**Pennsylvania**<center>|ACT|<center>0.20<center>|
# |2017|<center>Maryland<center>|ACT|<center>0.28<center>||2018|<center>Michigan<center>|ACT|<center>0.22<center>|
# |2017|<center>Vermont<center>|ACT|<center>0.29<center>||2018|<center>Washington<center>|ACT|<center>0.24<center>|
#
# <br>
#
# <h3 align="center">Top 7 States with Lowest SAT Participation, Ranked</h3>
#
# |Year|<center>State<center>|Exam|Participation Rate||Year|State|Exam|Participation Rate|
# |----|-----|----|------------------|-|----|-----|----|------------------|
# |2017|<center>**North Dakota**<center>|SAT|<center>0.02<center>||2018|<center>**North Dakota**<center>|SAT|<center>0.02<center>|<center>0.07<center>|
# |2017|<center>**Mississippi**<center>|SAT|<center>0.02<center>||2018|<center>Wyoming<center>|SAT|<center>0.03<center>|
# |2017|<center>**Iowa**<center>|SAT|<center>0.02<center>||2018|<center>**South Dakota**<center>|SAT|<center>0.03<center>|
# |2017|<center>Missouri<center>|SAT|<center>0.03<center>||2018|<center>**Nebraska**<center>|SAT|<center>0.03<center>|
# |2017|<center>Utah<center>|SAT|<center>0.03<center>||2018|<center>Wisconsin<center>|SAT|<center>0.03<center>|
# |2017|<center>**South Dakota**<center>|SAT|<center>0.03<center>||2018|<center>**Mississippi**<center>|SAT|<center>0.03<center>|
# |2017|<center>**Nebraska**<center>|SAT|<center>0.03<center>||2018|<center>**Iowa**<center>|SAT|<center>0.03<center>|

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Heatmap

plt.figure(figsize=(15, 15))

sns.heatmap(np.abs(df.corr()), annot=True);

# %% [markdown]
# Heatmaps of the correlation between all variables.
# Observations:
# 1. Strong positive correlation between 2017 and 2018 ACT participation rates (0.92).
#
#
# 2. Strong positive correlation between 2017 and 2018 SAT participation rates (0.82).
#
#
# 3. Strong positive correlation between participation rates and exam results:
#
# |Year|Exam|r^2|
# |---|---|---|
# |2017|ACT|0.86|
# ||SAT|0.87|
# |2018|ACT|0.86|
# ||SAT|0.79|
#
# 4. Moderate positive correlation between median income and exam results. Greater correlation between ACT results to income as compared to SAT results to income.
#
# |Year|Exam|Exam Total/Composite|Participation Rate|
# |---|---|---|---|
# |2017 |ACT|<center>0.56 <center>| <center>0.44<center>|
# | |SAT|<center>0.25<center> | <center>0.43<center>|
# |2018 |ACT|<center>0.58 <center>| <center>0.48<center>|
# | |SAT |<center>0.24<center> | <center>0.45<center>|

# %%
plt.figure(figsize=(15, 20))

plt.subplot(4, 3, 1)
plt.hist(
    df["act_2017_part"],
    bins=25,
)
plt.ylabel("Count of States")
plt.xlabel("2017 ACT Participation Rate")


plt.subplot(4, 3, 2)
plt.hist(
    df["act_2017_comp"],
    bins=15,
)
plt.ylabel("Count of States")
plt.xlabel("2017 ACT Composite Score")


plt.subplot(4, 3, 3)
plt.hist(
    df["2017_median_income"],
    bins=15,
)
plt.ylabel("Count of States")
plt.xlabel("2017 Household Income")


plt.subplot(4, 3, 4)
plt.hist(
    df["act_2018_part"],
    bins=25,
)
plt.ylabel("Count of States")
plt.xlabel("2018 ACT Participation Rate")


plt.subplot(4, 3, 5)
plt.hist(
    df["act_2018_comp"],
    bins=15,
)
plt.ylabel("Count of States")
plt.xlabel("2018 ACT Composite Score")


plt.subplot(4, 3, 6)
plt.hist(
    df["2018_median_income"],
    bins=15,
)
plt.ylabel("Count of States")
plt.xlabel("2018 Household Income");


plt.subplot(4, 3, 7)
plt.hist(
    df["sat_2017_part"],
    bins=25,
)
plt.ylabel("Count of States")
plt.xlabel("2017 SAT Participation Rate")


plt.subplot(4, 3, 8)
plt.hist(
    df["sat_2017_total"],
    bins=15,
)
plt.ylabel("Count of States")
plt.xlabel("2017 SAT Total Score")


plt.subplot(4, 3, 10)
plt.hist(
    df["sat_2018_part"],
    bins=25,
)
plt.ylabel("Count of States")
plt.xlabel("2018 SAT Participation Rate")


plt.subplot(4, 3, 11)
plt.hist(
    df["sat_2018_total"],
    bins=15,
)
plt.ylabel("Count of States")
plt.xlabel("2018 SAT Total Score");

# %% [markdown]
# Histogram of total scores of 2017 and 2018 ACT, SAT, and median household income. Observations:
# 1. There is a trend of high participation rate in ACT in both 2017 and 2018 as compared to SAT participation rates in the same years.
#
# 2. From 2017 to 2018, there is an increase in number of states getting lower scores.

# %%
sns.displot(data=[df["act_2017_part"], df["act_2018_part"]], \
            alpha=0.4, kind="hist", legend=False)
plt.xlabel("Participation Rate")
plt.ylabel("Number of States")
plt.legend(["2017 ACT Participation Rate", "2018 ACT Participation Rate"]);

# %% [markdown]
# ### Observation: There is a trend of decreasing ACT participation between 2017 and 2018.
#
# Looking at the bars that do not overlap, we see orange bars exceeding the overlap with blue bars on the left, while more blue bars exceed the overlap on the right. This shows a general trend of decreasing ACT participation as there is lower participation rate in the 2018 ACT as compared to 2017 ACT.
# </br>

# %%
sns.displot(data=[df["sat_2017_part"], df["sat_2018_part"]], \
            alpha=0.4, kind="hist", legend=False)
plt.xlabel("Participation Rate")
plt.ylabel("Number of States")
plt.legend(["2017 SAT Participation Rate", "2018 SAT Participation Rate"]);

# %% [markdown]
# ### Observation: There is a trend of increasing SAT participation between 2017 and 2018.
#
# Looking at the bars that do not overlap, we see orange bars exceeding the overlap with blue bars on the right, while more blue bars exceed the overlap on the left. This shows a general trend of increasing SAT participation as there is higher participation rate in the 2018 SAT as compared to 2017 SAT.
# </br>

# %%
sns.displot(data=[df["act_2017_comp"], df["act_2018_comp"]],
            alpha=1,
            kind="kde",
            legend=False)
plt.legend(["2017 ACT Composite Score", "2018 ACT Composite Score"]);

# %%
sns.displot(data=[df["sat_2017_total"], df["sat_2018_total"]],
            alpha=1,
            kind="kde", 
            legend=False)
plt.legend(["2017 SAT Total Score", "2018 SAT Total Score"]);

# %% [markdown]
# ### Observation: In both years, the composite/total score of each exam seems to be bimodal.
#
# For ACT, the two peaks are at about 20.5 and 23.8, while for SAT, the two peaks are at about 1080 and 1260. Also notable is a significant increase in SAT score distribution on the second (1260) peak between 2017 and 2018.

# %%
# df.drop(51, inplace=True)
df.head()
# Out:
#         state  act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 0     alabama           1.00          18.9           18.4           19.7
# 1      alaska           0.65          18.7           19.8           20.4
# 2     arizona           0.62          18.6           19.8           20.1
# 3    arkansas           1.00          18.9           19.0           19.7
# 4  california           0.31          22.5           22.7           23.1
#
#    act_2017_sci  act_2017_comp  act_2018_part  act_2018_comp  sat_2017_part  \
# 0          19.4           19.2           1.00           19.1           0.05
# 1          19.9           19.8           0.33           20.8           0.38
# 2          19.8           19.7           0.66           19.2           0.30
# 3          19.5           19.4           1.00           19.4           0.03
# 4          22.2           22.8           0.27           22.7           0.53
#
# ...

# %%
def top_half(row):
    if row["2018_median_income"] > np.mean(df["2018_median_income"]):
        row["top_half_income_2018"] = 1
    else:
        row["top_half_income_2018"] = 0
    if row["2017_median_income"] > np.mean(df["2017_median_income"]):
        row["top_half_income_2017"] = 1
    else:
        row["top_half_income_2017"] = 0   
    return row

            
df = df.apply(top_half, axis=1)
df.head()
# Out:
#         state  act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 0     alabama           1.00          18.9           18.4           19.7
# 1      alaska           0.65          18.7           19.8           20.4
# 2     arizona           0.62          18.6           19.8           20.1
# 3    arkansas           1.00          18.9           19.0           19.7
# 4  california           0.31          22.5           22.7           23.1
#
#    act_2017_sci  act_2017_comp  act_2018_part  act_2018_comp  sat_2017_part  \
# 0          19.4           19.2           1.00           19.1           0.05
# 1          19.9           19.8           0.33           20.8           0.38
# 2          19.8           19.7           0.66           19.2           0.30
# 3          19.5           19.4           1.00           19.4           0.03
# 4          22.2           22.8           0.27           22.7           0.53
#
# ...

# %%
sns.displot(data=[df["2018_median_income"], df["2017_median_income"]],
            alpha=0.5,
            kind="kde"
           );

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10))

plt.subplot(2,4,1)
sns.regplot(data=df, x="2017_median_income", y="act_2017_part").set(ylim=(0,1.05))

plt.subplot(2,4,2)
sns.regplot(data=df, x="2017_median_income", y="act_2017_comp")

plt.subplot(2,4,3)
sns.regplot(data=df, x="2017_median_income", y="sat_2017_part").set(ylim=(-0.05, 1.05))

plt.subplot(2,4,4)
sns.regplot(data=df, x="2017_median_income", y="sat_2017_total")

plt.subplot(2,4,5)
sns.regplot(data=df, x="2018_median_income", y="act_2018_part").set(ylim=(0,1.05))

plt.subplot(2,4,6)
sns.regplot(data=df, x="2018_median_income", y="act_2018_comp")

plt.subplot(2,4,7)
sns.regplot(data=df, x="2018_median_income", y="sat_2018_part").set(ylim=(-0.05, 1.05))

plt.subplot(2,4,8)
sns.regplot(data=df, x="2018_median_income", y="sat_2018_total");

# %%
plt.figure(figsize=(18, 16));

sns.pairplot(df, 
             hue='top_half_income_2017', 
             x_vars=["act_2017_part", "act_2017_comp",
                     "sat_2017_part", "sat_2017_total"],
             y_vars=["act_2017_part", "act_2017_comp",
                     "sat_2017_part", "sat_2017_total"],
            );

# %%
plt.figure(figsize=(18, 16))

sns.pairplot(df, 
             hue='top_half_income_2018', 
             x_vars=["act_2018_part", "act_2018_comp",
                     "sat_2018_part", "sat_2018_total"],
             y_vars=["act_2018_part", "act_2018_comp",
                     "sat_2018_part", "sat_2018_total"],
             );

# %% [markdown]
# ### Observation: Results from regressing median household income to participation and results of both exams are mixed.
#
# Regressing median household income to participation, we see that there while there is a positive correlation between household income levels and exam scores. On the other hand, the results are mixed for participation, with higher income households participating less in the ACT and more in SAT. When grouped by whether a state’s median household income is in the top or bottom half nationally, there is a stronger trend that households which have higher median incomes do better on both exams. Similar to the previous observation, as household income increases, participation rate drops for ACT while it increases for SAT.

# %%
sns.pairplot(df, hue='top_half_income_2018');

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Previous researches have suggested that there exists a link between household income levels and ACT and SAT scores.
# Overall, there is a mixed result between household income and examination participation and score.
# However, when grouped by top and bottom half income levels, the observations above show there is a trend for household income levels to be positively correlated with higher exam scores.
#
# On the participation rates, the trends of participation on household incomes increase produce mixed results.
# Exam participation and results by state are persistent through the years, and states with greater participation in an exam show greater results as compared to states with lower participation.
# This suggests that there may be a third factor such as race or state level policies that may play a role in the participation of examinations and its resulting scores ([*source*](https://www.insidehighered.com/news/2010/06/21/new-evidence-racial-bias-sat)).
# Such persistence may suggest that there are state-level reasons for the persistence of such trend.
# For instance, states may have differing level of preference which may result in the difference in state participation rates of such exams. Notably, Western and North Eastern states such as California and New Hampshire tend to prefer the SATs while Mid-West states such as Wisconsin, Arkansas and Oklahoma prefer the ACTs ([*source*](https://www.collegeraptor.com/getting-in/articles/act-sat/preference-act-sat-state-infographic/)).
# As such, while grouping by top and bottom half income levels suggest a trend for household income levels to be positively correlated with higher exam scores, we recommend looking into and taking other factors into consideration when deciding whether federal funding should be increased to increase the rate of participation and results of ACT and SAT exams.
